# %% [markdown]
# **Spam Deduction AutoML SDK**

# %%
import azureml.core
from azureml.core import Workspace

import logging
import os
import csv
from datetime import datetime
import pytz


from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import seaborn as sns
import tensorflow as tf

import matplotlib.pyplot as plt
import re
import pydot
import graphviz

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

print("Azure SDK version: ", azureml.core.VERSION)
print("Tensorflow version: ", tf.__version__)
# Out:
# Azure SDK version:  1.44.0
# Tensorflow version:  2.9.1

# %% [markdown]
# **Initialize and Access Workspace**

# %%
# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))

print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')
print("Current DateTime: ", datetime.now(pytz.timezone("America/New_York")).strftime("%m/%d/%Y %H:%M:%S"))
# Out:
# Performing interactive authentication. Please follow the instructions on the terminal.
# The default web browser has been opened at https://login.microsoftonline.com/organizations/oauth2/v2.0/authorize. Please continue the login in the web browser. If no web browser is available or if the web browser fails to open, use device code flow with `az login --use-device-code`.
# Interactive authentication successfully completed.
# Ready to use Azure ML 1.44.0 to work with nahmed30-azureml-workspace
# nahmed30-azureml-workspace
# epe-poc-nazeer
# centralus
# 16bc73b5-82be-47f2-b5ab-f2373344794c
# Current DateTime:  08/31/2022 13:27:19

# %% [markdown]
# **Create an AzureML Experiment**

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_folder = 'email_spam_automl_experiments'
experiment_name = 'email-spam-automl-experiment1'
project_folder = 'email_spam_automl_project'

os.makedirs(project_folder, exist_ok=True)

print('Project Folder is ready.')

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Project Folder is ready.
# Experiment(Name: email-spam-automl-experiment1,
# Workspace: nahmed30-azureml-workspace)

# %% [markdown]
# **Create Compute**

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "cpu-cluster"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded....................................................................................................
# AmlCompute wait for completion finished
#
# Wait timeout has been reached
# Current provisioning state of AmlCompute is "Succeeded" and current node count is "0"

# %%
# %%writefile $project_folder/hyperdrive_env.yml
# name: batch_environment
# dependencies:
# - python
# - scikit-learn
# - pandas
# - numpy
# - pip
# - pip:
#   - azureml-defaults
# Out:
# Overwriting email_spam_automl_project/hyperdrive_env.yml

# %% [markdown]
# **Prepare Data**

# %%
# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "UdacityPrjEmailSpamDataSet"
description_text = "Email Spam Detection DataSet for Udacity Capstone Proj "

dataset = None
if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

if not found:
        # Create AML Dataset and register it into Workspace
        spam_data = 'https://www.kaggle.com/code/rumbleftw/beginner-friendly-spam-ham-sms-classification/data#:~:text=calendar_view_week-,spam,-.csv'
        dataset = Dataset.Tabular.from_delimited_files(spam_data)        
        #Register Dataset in Workspace
        dataset = dataset.register(workspace=ws,
                                   name=key,
                                   description=description_text)


df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#           v1                      v2  \
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30
#
#                                                   Column3  \
# count                                                  50
# unique                                                 43
# top      bt not his girlfrnd... G o o d n i g h t . . .@"
# freq                                                    3
#
#                       Column4  Column5
# count                      12        6
# unique                     10        5
# top      MK17 92H. 450Ppw 16"  GNT:-)"
# freq                        2        2

# %% [markdown]
# **Review Dataset Results**

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#      v1                                                 v2 Column3 Column4  \
# 0   ham  Go until jurong point, crazy.. Available only ...    None    None
# 1   ham                      Ok lar... Joking wif u oni...    None    None
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...    None    None
# 3   ham  U dun say so early hor... U c already then say...    None    None
# 4   ham  Nah I don't think he goes to usf, he lives aro...    None    None
#
#   Column5
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None

# %% [markdown]
# **Train and Test SPLIT**
#
# https://docs.microsoft.com/en-us/azure/machine-learning/how-to-configure-cross-validation-data-splits

# %%
train_data, validate_data = dataset.random_split(percentage=0.8, seed=1)

# %% [markdown]
# **AutoML to Train**

# %%
automl_settings = {
    "experiment_timeout_minutes": 20,
    "max_concurrent_iterations": 4,
    "primary_metric" : 'accuracy',
    "n_cross_validations": 5
}

automl_config = AutoMLConfig(compute_target=compute_target,
                             task = "classification",
                             training_data=dataset,
                             label_column_name="v1",  
                             path = project_folder,
                             enable_early_stopping= True,
                             test_size=0.2,
                             featurization= 'auto',
                             debug_log = "email_spam_automl_errors.log",
                             **automl_settings
                            )

# %% [markdown]
# **Create Pipeline and AutoMLStep**
#
# You can define outputs for the AutoMLStep using TrainingOutput.

# %%
from azureml.pipeline.core import PipelineData, TrainingOutput

ds = ws.get_default_datastore()

metrics_output_name = 'emailspam_metrics_output'
best_model_output_name = 'emailspam_best_model_output'

metrics_data = PipelineData(name='emailspam_metrics_data',
                           datastore=ds,
                           pipeline_output_name=metrics_output_name,
                           training_output=TrainingOutput(type='Metrics'))
model_data = PipelineData(name='emailspam_model_data',
                           datastore=ds,
                           pipeline_output_name=best_model_output_name,
                           training_output=TrainingOutput(type='Model'))

# %% [markdown]
# Create an AutoMLStep.

# %%
automl_step = AutoMLStep(
    name='spamemail_automl_module',
    automl_config=automl_config,
    outputs=[metrics_data, model_data],
    allow_reuse=True)

# %% [markdown]
# Add AutoMLStep to Pipeline

# %%
from azureml.pipeline.core import Pipeline
pipeline = Pipeline(
    description="emailspam_pipeline_with_automlstep",
    workspace=ws,    
    steps=[automl_step])

# %% [markdown]
# Submit Pipeline Experiment

# %%
pipeline_run = experiment.submit(pipeline)
# Out:
# Created step spamemail_automl_module [8946a466][7485c5f0-0c5f-46a0-a3fa-fc852c95390f], (This step will run and generate new outputs)
# Submitted PipelineRun ff4ac578-a878-4f37-8a32-845b10670b55
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/ff4ac578-a878-4f37-8a32-845b10670b55?wsid=/subscriptions/16bc73b5-82be-47f2-b5ab-f2373344794c/resourcegroups/epe-poc-nazeer/workspaces/nahmed30-azureml-workspace&tid=db05faca-c82a-4b9d-b9c5-0f64b6755421

# %%
from azureml.widgets import RunDetails
RunDetails(pipeline_run).show()

# %%
pipeline_run.wait_for_completion()
# Out:
# PipelineRunId: ff4ac578-a878-4f37-8a32-845b10670b55
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/ff4ac578-a878-4f37-8a32-845b10670b55?wsid=/subscriptions/16bc73b5-82be-47f2-b5ab-f2373344794c/resourcegroups/epe-poc-nazeer/workspaces/nahmed30-azureml-workspace&tid=db05faca-c82a-4b9d-b9c5-0f64b6755421
# PipelineRun Status: Running
#
#
# StepRunId: 19a393c8-0f5a-4a64-b891-a802346138e5
# Link to Azure Machine Learning Portal: https://ml.azure.com/runs/19a393c8-0f5a-4a64-b891-a802346138e5?wsid=/subscriptions/16bc73b5-82be-47f2-b5ab-f2373344794c/resourcegroups/epe-poc-nazeer/workspaces/nahmed30-azureml-workspace&tid=db05faca-c82a-4b9d-b9c5-0f64b6755421
# StepRun( spamemail_automl_module ) Status: Running
#
# StepRun(spamemail_automl_module) Execution Summary
# ===================================================
# StepRun( spamemail_automl_module ) Status: Finished
#
# Warnings:
# No scores improved over last 10 iterations, so experiment stopped early. This early stopping behavior can be disabled by setting enable_early_stopping = False in AutoMLConfig for notebook/python SDK runs.
# {'runId': '19a393c8-0f5a-4a64-b891-a802346138e5', 'target': 'cpu-cluster', 'status': 'Completed', 'startTimeUtc': '2022-08-31T18:08:41.42074Z', 'endTimeUtc': '2022-08-31T18:28:13.303184Z', 'services': {}, 'warnings': [{'source': 'JasmineService', 'message': 'No scores improved over last 10 iterations, so experiment stopped early. This early stopping behavior can be disabled by setting enable_early_stopping = False in AutoMLConfig for notebook/python SDK runs.'}], 'properties': {'ContentSnapshotId': '5ac6ef0f-ba87-422f-86cd-6f1f253ac74e', 'StepType': 'AutoMLStep', 'azureml.moduleid': '7485c5f0-0c5f-46a0-a3fa-fc852c95390f', 'azureml.moduleName': 'spamemail_automl_module', 'azureml.runsource': 'azureml.StepRun', 'azureml.nodeid': '8946a466', 'azureml.pipelinerunid': 'ff4ac578-a878-4f37-8a32-845b10670b55', 'azureml.pipeline': 'ff4ac578-a878-4f37-8a32-845b10670b55', 'azureml.pipelineComponent': 'masterautomlcloud', 'num_iterations': '1000', 'training_type': 'TrainFull', 'acquisition_function': 'EI', 'metrics': 'accuracy', 'primary_metric': 'accuracy', 'train_split': '0', 'MaxTimeSeconds': None, 'acquisition_parameter': '0', 'num_cross_validation': '5', 'target': 'cpu-cluster', 'RawAMLSettingsString': None, 'AMLSettingsJsonString': '{"path": null, "name": "placeholder", "subscription_id": "16bc73b5-82be-47f2-b5ab-f2373344794c", "resource_group": "epe-poc-nazeer", "workspace_name": "nahmed30-azureml-workspace", "region": "centralus", "compute_target": "cpu-cluster", "spark_service": null, "azure_service": null, "many_models": false, "pipeline_fetch_max_batch_size": 1, "enable_batch_run": false, "enable_run_restructure": false, "start_auxiliary_runs_before_parent_complete": true, "enable_code_generation": true, "iterations": 1000, "primary_metric": "accuracy", "task_type": "classification", "positive_label": null, "data_script": null, "test_size": 0.2, "test_include_predictions_only": false, "validation_size": 0.0, "n_cross_validations": 5, "y_min": null, "y_max": null, "num_classes": null, "featurization": "auto", "_ignore_package_version_incompatibilities": false, "is_timeseries": false, "max_cores_per_iteration": 1, "max_concurrent_iterations": 4, "iteration_timeout_minutes": null, "mem_in_mb": null, "enforce_time_on_windows": false, "experiment_timeout_minutes": 20, "experiment_exit_score": null, "partition_column_names": null, "whitelist_models": null, "blacklist_algos": null, "supported_models": ["LinearSVM", "XGBoostClassifier", "MultinomialNaiveBayes", "TabnetClassifier", "LogisticRegression", "TensorFlowLinearClassifier", "LightGBM", "AveragedPerceptronClassifier", "BernoulliNaiveBayes", "KNN", "DecisionTree", "TensorFlowDNN", "ExtremeRandomTrees", "SVM", "GradientBoosting", "SGD", "RandomForest"], "private_models": [], "auto_blacklist": true, "blacklist_samples_reached": false, "exclude_nan_labels": true, "verbosity": 20, "_debug_log": "email_spam_automl_errors.log", "show_warnings": false, "model_explainability": true, "service_url": null, "sdk_url": null, "sdk_packages": null, "enable_onnx_compatible_models": false, "enable_split_onnx_featurizer_estimator_models": false, "vm_type": "STANDARD_DS12_V2", "telemetry_verbosity": 20, "send_telemetry": true, "enable_dnn": false, "scenario": "AutoML", "environment_label": null, "save_mlflow": false, "enable_categorical_indicators": false, "force_text_dnn": false, "enable_feature_sweeping": true, "enable_early_stopping": true, "early_stopping_n_iters": 10, "arguments": null, "dataset_id": null, "hyperdrive_config": null, "validation_dataset_id": null, "run_source": null, "metrics": null, "enable_metric_confidence": false, "enable_ensembling": true, "enable_stack_ensembling": true, "ensemble_iterations": 15, "enable_tf": false, "enable_subsampling": null, "subsample_seed": null, "enable_nimbusml": false, "enable_streaming": false, "force_streaming": false, "track_child_runs": true, "allowed_private_models": [], "label_column_name": "v1", "weight_column_name": null, "cv_split_column_ ...
#
#
#
# PipelineRun Execution Summary
# ==============================
# PipelineRun Status: Finished
# {'runId': 'ff4ac578-a878-4f37-8a32-845b10670b55', 'status': 'Completed', 'startTimeUtc': '2022-08-31T18:08:27.24227Z', 'endTimeUtc': '2022-08-31T18:28:35.002155Z', 'services': {}, 'properties': {'azureml.runsource': 'azureml.PipelineRun', 'runSource': 'SDK', 'runType': 'SDK', 'azureml.parameters': '{}', 'azureml.continue_on_step_failure': 'False', 'azureml.continue_on_failed_optional_input': 'True', 'azureml.pipelineComponent': 'pipelinerun'}, 'inputDatasets': [], 'outputDatasets': [], 'logFiles': {'logs/azureml/executionlogs.txt': 'https://nahmed30storage.blob.core.windows.net/azureml/ExperimentRun/dcid.ff4ac578-a878-4f37-8a32-845b10670b55/logs/azureml/executionlogs.txt?sv=2019-07-07&sr=b&sig=nwHQNq%2B%2FH07IWkBz%2FMsdiuJ%2FVQ819IkgVnSP%2FFMeqTo%3D&skoid=990e57a2-6b09-4324-b33f-71ef714de994&sktid=db05faca-c82a-4b9d-b9c5-0f64b6755421&skt=2022-08-31T15%3A29%3A18Z&ske=2022-09-01T23%3A39%3A18Z&sks=b&skv=2019-07-07&st=2022-08-31T18%3A18%3A40Z&se=2022-09-01T02%3A28%3A40Z&sp=r', 'logs/azureml/stderrlogs.txt': 'https://nahmed30storage.blob.core.windows.net/azureml/ExperimentRun/dcid.ff4ac578-a878-4f37-8a32-845b10670b55/logs/azureml/stderrlogs.txt?sv=2019-07-07&sr=b&sig=4w4rcCC96nqMtAVZ6e3vdVRWa32Dj4%2F9NuXqehnJ4rk%3D&skoid=990e57a2-6b09-4324-b33f-71ef714de994&sktid=db05faca-c82a-4b9d-b9c5-0f64b6755421&skt=2022-08-31T15%3A29%3A18Z&ske=2022-09-01T23%3A39%3A18Z&sks=b&skv=2019-07-07&st=2022-08-31T18%3A18%3A40Z&se=2022-09-01T02%3A28%3A40Z&sp=r', 'logs/azureml/stdoutlogs.txt': 'https://nahmed30storage.blob.core.windows.net/azureml/ExperimentRun/dcid.ff4ac578-a878-4f37-8a32-845b10670b55/logs/azureml/stdoutlogs.txt?sv=2019-07-07&sr=b&sig=9SQoVQjYexJhhcOf8N%2B%2FAS3trJmocMtVXvA2u9XTXtY%3D&skoid=990e57a2-6b09-4324-b33f-71ef714de994&sktid=db05faca-c82a-4b9d-b9c5-0f64b6755421&skt=2022-08-31T15%3A29%3A18Z&ske=2022-09-01T23%3A39%3A18Z&sks=b&skv=2019-07-07&st=2022-08-31T18%3A18%3A40Z&se=2022-09-01T02%3A28%3A40Z&sp=r'}, 'submittedBy': 'Nazeer Ahmed'}
# 'Finished'

# %% [markdown]
# **Examine Results**
#
# *Retrieve the metrics of all child runs*
#
# Outputs of above run can be used as inputs of other steps in pipeline. In this tutorial, we will examine the outputs by retrieve output data and running some tests.

# %%
metrics_output = pipeline_run.get_pipeline_output(metrics_output_name)
num_file_downloaded = metrics_output.download('./email_spam_automl_project', show_progress=True)
# Out:
# Downloading azureml/19a393c8-0f5a-4a64-b891-a802346138e5/emailspam_metrics_data
# Downloaded azureml/19a393c8-0f5a-4a64-b891-a802346138e5/emailspam_metrics_data, 1 files out of an estimated total of 1

# %% [markdown]
# **Retrive Best Model**

# %%
import json
with open(metrics_output._path_on_datastore) as f:
    metrics_output_result = f.read()
    
deserialized_metrics_output = json.loads(metrics_output_result)
df = pd.DataFrame(deserialized_metrics_output)
df
# Out:
#                                  19a393c8-0f5a-4a64-b891-a802346138e5_0  \
# average_precision_score_micro                      [0.9974021899666828]
# recall_score_micro                                 [0.9856414166578592]
# log_loss                                          [0.07148743074855661]
# norm_macro_recall                                  [0.9023107402861952]
# weighted_accuracy                                  [0.9961627075188704]
# AUC_macro                                          [0.9930908888539735]
# f1_score_macro                                     [0.9680895029505227]
# accuracy                                           [0.9856414166578592]
# f1_score_weighted                                  [0.9853610423786494]
# AUC_micro                                          [0.9974498562111315]
# AUC_weighted                                       [0.9930908888539733]
# precision_score_macro                              [0.9870878391853459]
# average_precision_score_weighted                   [0.9963092888577314]
# matthews_correlation                               [0.9375206868048475]
# balanced_accuracy                                  [0.9511553701430977]
# f1_score_micro                                     [0.9856414166578592]
# recall_score_weighted                              [0.9856414166578592]
# precision_score_micro                              [0.9856414166578592]
# recall_score_macro                                 [0.9511553701430977]
# average_precision_score_macro                      [0.9901016723515861]
# precision_score_weighted                           [0.9857155788905754]
#
#                                  19a393c8-0f5a-4a64-b891-a802346138e5_2  \
# average_precision_score_micro                      [0.9941713301400481]
# recall_score_micro                                 [0.9670194722511614]
# log_loss                                            [0.591594053028278]
# norm_macro_recall                                  [0.8624266370993598]
# weighted_accuracy                                  [0.9777621175543569]
# AUC_macro                                          [0.9847568074251501]
# f1_score_macro                                     [0.9291167292593171]
# accuracy                                           [0.9670194722511614]
# f1_score_weighted                                  [0.9670979785167779]
# AUC_micro                                          [0.9941819003491359]
# AUC_weighted                                       [0.9847568074251501]
# precision_score_macro                              [0.9274289403987929]
# average_precision_score_weighted                   [0.9907412951110779]
# matthews_correlation                               [0.8584999913324495]
# balanced_accuracy                                  [0.9312133185496799]
# f1_score_micro                                     [0.9670194722511614]
# recall_score_weighted                              [0.9670194722511614]
# precision_score_micro                              [0.9670194722511614]
# recall_score_macro                                 [0.9312133185496799]
# average_precision_score_macro                      [0.9731534725243863]
# precision_score_weighted                           [0.9672944387849831]
#
#                                  19a393c8-0f5a-4a64-b891-a802346138e5_3  \
# average_precision_score_micro                      [0.9863255165205846]
# recall_score_micro                                 [0.9744238599246072]
# log_loss                                           [0.6117418881648135]
# norm_macro_recall                                  [0.8265477514909485]
# weighted_accuracy                                  [0.9930995397008731]
# AUC_macro                                          [0.9696018516207632]
# f1_score_macro                                     [0.9413725757739752]
# accuracy                                           [0.9744238599246072]
# f1_score_weighted                                  [0.9735046839386887]
# AUC_micro                                           [0.990151115963678]
# AUC_weighted                                       [0.9696018516207632]
# precision_score_macro                              [0.9763032291431919]
# average_precision_score_weighted                   [0.9843166815144363]
# matthews_correlation                               [0.8871600718276837]
# balanced_accuracy                                  [0.9132738757454743]
# f1_score_micro                                     [0.9744238599246072]
# recall_score_weighted                              [0.9744238599246072]
# precision_score_micro                              [0.9744238599246072]
# recall_score_macro                                 [0.9132738757454743]
# average_precision_score_macro                      [0.9668250568632825]
# precision_score_weighted                           [0.9746865905528285]
#
#                                  19a393c8-0f5a-4a64-b891-a802346138e5_1  \
# average_precision_score_micro                      [0.9957460984878426]
# recall_score_micro                                 [0.9845193338466881]
# log_loss                                          [0.06079730247665531]
# norm_macro_recall                                  [0.8892466091575478]
# weighted_accuracy                                  [0.9966167821894978]
# AUC_macro                                          [0.9883755323097068]
# f1_score_macro                                     [0.9651940676699379]
# accuracy                                           [0.9845193338466881]
# f1_score_weighted                                   [0.984131478084041]
# AUC_micro                                           [0.996226254610808]
# AUC_weighted                                       [0.9883755323097067]
# precision_score_macro                              [0.9889703652028832]
# average_precision_score_weighted                   [0.9941733156339569]
# matthews_correlation                               [0.9324568321939457]
# balanced_accuracy                                   [0.944623304578774]
# f1_score_micro                                     [0.9845193338466881]
# recall_score_weighted                              [0.9845193338466881]
# precision_score_micro                              [0.9845193338466881]
# recall_score_macro                                  [0.944623304578774]
# average_precision_score_macro                       [0.986480628517995]
# precision_score_weighted                           [0.9847088050141721]
#
#                                  19a393c8-0f5a-4a64-b891-a802346138e5_4  \
# average_precision_score_micro                      [0.9933769473610221]
# recall_score_micro                                 [0.9768924924380828]
# log_loss                                          [0.09410963185901053]
# norm_macro_recall                                  [0.8329523259077953]
# weighted_accuracy                                  [0.9952564829278984]
# AUC_macro                                          [0.9852439476783298]
# f1_score_macro                                     [0.9467544785321607]
# accuracy                                           [0.9768924924380828]
# f1_score_weighted                                  [0.9760014890325206]
# AUC_micro                                          [0.9939997465958674]
# AUC_weighted                                       [0.9852439476783298]
# precision_score_macro                              [0.9843652299534167]
# average_precision_score_weighted                   [0.9922445459392726]
# matthews_correlation                               [0.8982293942070992]
# balanced_accuracy                                  [0.9164761629538976]
# f1_score_micro                                     [0.9768924924380828]
# recall_score_weighted                              [0.9768924924380828]
# precision_score_micro                              [0.9768924924380828]
# recall_score_macro                                 [0.9164761629538976]
# average_precision_score_macro                      [0.9807736863803804]
# precision_score_weighted                           [0.9773291441121289]
#
#                                  19a393c8-0f5a-4a64-b891-a802346138e5_5  \
# average_precision_score_micro                      [0.9820116222061792]
# recall_score_micro                                 [0.9394241367335538]
# log_loss                                          [0.19699072741529194]
# norm_macro_recall                                  [0.5484772613804871]
# weighted_accuracy                                  [0.9893228017557714]
# AUC_macro                                           [0.977109261709912]
# f1_score_macro                                     [0.8370290422702968]
# accuracy                                           [0.9394241367335538]
# f1_score_weighted                                  [0.9315583991913347]
# AUC_micro                                          [0.9840836931960772]
# AUC_weighted                                        [0.977109261709912]
# precision_score_macro                              [0.9672988824088808]
# average_precision_score_weighted                   [0.9880320206594316]
# matthews_correlation                               [0.7157064141716216]
# balanced_accuracy                                  [0.7742386306902436]
# f1_score_micro                                     [0.9394241367335538]
# recall_score_weighted                              [0.9394241367335538]
# precision_score_micro                              [0.9394241367335538]
# recall_score_macro                                 [0.7742386306902436]
# average_precision_score_macro                      [0.9740790116378915]
# precision_score_weighted                           [0.9434252483545175]
#
#                                  19a393c8-0f5a-4a64-b891-a802346138e5_13  \
# average_precision_score_micro                        [0.996571234231763]
# recall_score_micro                                  [0.9883330061954876]
# log_loss                                           [0.09164538870615606]
# norm_macro_recall                                   [0.9210555076949574]
# weighted_accuracy                                   [0.9968455940041251]
# AUC_macro                                           [0.9918513297835071]
# f1_score_macro                                      [0.9743414632338517]
# accuracy                                            [0.9883330061954876]
# f1_score_weighted                                   [0.9881443612021995]
# AUC_micro                                           [0.9974777062033493]
# AUC_weighted                                        [0.9918513297835071]
# precision_score_macro                               [0.9894826900367797]
# average_precision_score_weighted                    [0.9957406427982715]
# matthews_correlation                                [0.9495482186825035]
# balanced_accuracy                                   [0.9605277538474788]
# f1_score_micro                                      [0.9883330061954876]
# recall_score_weighted                               [0.9883330061954876]
# precision_score_micro                               [0.9883330061954876]
# recall_score_macro                                  [0.9605277538474788]
# average_precision_score_macro                       [0.9909807804217732]
# precision_score_weighted                              [0.98836639049903]
#
#                                  19a393c8-0f5a-4a64-b891-a802346138e5_7  \
# average_precision_score_micro                      [0.9981758769794824]
# recall_score_micro                                 [0.9876608637445707]
# log_loss                                          [0.04284798513694774]
# norm_macro_recall                                  [0.9091387665581214]
# weighted_accuracy                                  [0.9977919809058147]
# AUC_macro                                          [0.9957472725041132]
# f1_score_macro                                      [0.972594184222034]
# accuracy                                           [0.9876608637445707]
# f1_score_weighted                                  [0.9873942195240166]
# AUC_micro                                          [0.9982372001168051]
# AUC_weighted                                       [0.9957472725041132]
# precision_score_macro                              [0.9929627819448668]
# average_precision_score_weighted                   [0.9977762497182476]
# matthews_correlation                               [0.9467102576405774]
# balanced_accuracy                                  [0.9545693832790606]
# f1_score_micro                                     [0.9876608637445707]
# recall_score_weighted                              [0.9876608637445707]
# precision_score_micro                              [0.9876608637445707]
# recall_score_macro                                 [0.9545693832790606]
# average_precision_score_macro                      [0.9942531690663845]
# precision_score_weighted                           [0.9878485454348944]
#
#                                  19a393c8-0f5a-4a64-b891-a802346138e5_8  \
# average_precision_score_micro                      [0.9916312838716872]
# recall_score_micro                                 [0.9584967764339961]
# log_loss                                          [0.14954982700084093]
# norm_macro_recall                                  [0.6947651224425417]
# weighted_accuracy                                  [0.9922226296373189]
# AUC_macro                                          [0.9863388329140641]
# f1_score_macro                                     [0.8968546042872703]
# accuracy                                           [0.9584967764339961]
# f1_score_weighted                                  [0.9551108574349932]
# AUC_micro                                          [0.9915564195418589]
# AUC_weighted                                       [0.9863388329140641]
# precision_score_macro                              [0.9747483610987111]
# average_precision_score_weighted                   [0.9926898126097674]
# matthews_correlation                               [0.8116549539570617]
# balanced_accuracy                                  [0.8473825612212709]
# f1_score_micro                                     [0.9584967764339961]
# recall_score_weighted                              [0.9584967764339961]
# precision_score_micro                              [0.9584967764339961]
# recall_score_macro                                 [0.8473825612212709]
# average_precision_score_macro                      [0.9799266724338891]
# precision_score_weighted                           [0.9601980224311264]
#
#                                  19a393c8-0f5a-4a64-b891-a802346138e5_9  ...  \
# average_precision_score_micro                      [0.9942057874206371]  ...
# recall_score_micro                                 [0.9800327641134816]  ...
# log_loss                                          [0.07424503582791869]  ...
# norm_macro_recall                                  [0.8601977847661573]  ...
# weighted_accuracy                                    [0.99518978871219]  ...
# AUC_macro                                          [0.9852918187275232]  ...
# f1_score_macro                                      [0.954492156239532]  ...
# accuracy                                           [0.9800327641134816]  ...
# f1_score_weighted                                  [0.9794242553157751]  ...
# AUC_micro                                          [0.9948772751193007]  ...
# AUC_weighted                                       [0.9852918187275232]  ...
# precision_score_macro                              [0.9836042872557877]  ...
# average_precision_score_weighted                   [0.9922784375522825]  ...
# matthews_correlation                               [0.9120306596063751]  ...
# balanced_accuracy                                  [0.9300988923830786]  ...
# f1_score_micro                                     [0.9800327641134816]  ...
# recall_score_weighted                              [0.9800327641134816]  ...
# precision_score_micro                              [0.9800327641134816]  ...
# recall_score_macro                                 [0.9300988923830786]  ...
# average_precision_score_macro                      [0.9813424782144656]  ...
# precision_score_weighted                           [0.9802474547306549]  ...
#
#                                  19a393c8-0f5a-4a64-b891-a802346138e5_31  \
# average_precision_score_micro                       [0.9965657352573427]
# recall_score_micro                                  [0.9840719099314018]
# log_loss                                           [0.05608078247970414]
# norm_macro_recall                                   [0.8864483369399208]
# weighted_accuracy                                   [0.9965182883304713]
# AUC_macro                                           [0.9903276629345961]
# f1_score_macro                                      [0.9643435757565518]
# accuracy                                            [0.9840719099314018]
# f1_score_weighted                                   [0.9836715792679158]
# AUC_micro                                           [0.9966717319841709]
# AUC_weighted                                        [0.9903276629345961]
# precision_score_macro                               [0.9886757480445191]
# average_precision_score_weighted                    [0.9951281701115535]
# matthews_correlation                                [0.9307659525603817]
# balanced_accuracy                                   [0.9432241684699605]
# f1_score_micro                                      [0.9840719099314018]
# recall_score_weighted                               [0.9840719099314018]
# precision_score_micro                               [0.9840719099314018]
# recall_score_macro                                  [0.9432241684699605]
# average_precision_score_macro                       [0.9875261819524773]
# precision_score_weighted                            [0.9842464715738692]
#
#                                  19a393c8-0f5a-4a64-b891-a802346138e5_30  \
# average_precision_score_micro                       [0.8168519111275538]
# recall_score_micro                                  [0.8658322135153226]
# log_loss                                           [0.39430986737770846]
# norm_macro_recall                                                  [0.0]
# weighted_accuracy                                   [0.9763446516633548]
# AUC_macro                                                          [0.5]
# f1_score_macro                                      [0.4640302758137837]
# accuracy                                            [0.8658322135153226]
# f1_score_weighted                                   [0.8036038754030779]
# AUC_micro                                           [0.8658322135153227]
# AUC_weighted                                                       [0.5]
# precision_score_macro                               [0.4329161067576613]
# average_precision_score_weighted                     [0.767871608739785]
# matthews_correlation                                               [0.0]
# balanced_accuracy                                                  [0.5]
# f1_score_micro                                      [0.8658322135153226]
# recall_score_weighted                               [0.8658322135153226]
# precision_score_micro                               [0.8658322135153226]
# recall_score_macro                                                 [0.5]
# average_precision_score_macro                                      [0.5]
# precision_score_weighted                            [0.7497680178852152]
#
#                                  19a393c8-0f5a-4a64-b891-a802346138e5_17  \
# average_precision_score_micro                       [0.9946391296690995]
# recall_score_micro                                  [0.9730775618667995]
# log_loss                                           [0.10443498442790138]
# norm_macro_recall                                   [0.8107511829447314]
# weighted_accuracy                                   [0.9937269933751309]
# AUC_macro                                           [0.9875347081043057]
# f1_score_macro                                      [0.9373876479321781]
# accuracy                                            [0.9730775618667995]
# f1_score_weighted                                    [0.971919677573187]
# AUC_micro                                           [0.9946907155384596]
# AUC_weighted                                        [0.9875347081043057]
# precision_score_macro                               [0.9786075961729388]
# average_precision_score_weighted                    [0.9933211006240962]
# matthews_correlation                                [0.8807023233265093]
# balanced_accuracy                                   [0.9053755914723656]
# f1_score_micro                                      [0.9730775618667995]
# recall_score_weighted                               [0.9730775618667995]
# precision_score_micro                               [0.9730775618667995]
# recall_score_macro                                  [0.9053755914723656]
# average_precision_score_macro                       [0.9815986524047882]
# precision_score_weighted                            [0.9735787708040986]
#
#                                  19a393c8-0f5a-4a64-b891-a802346138e5_21  \
# average_precision_score_micro                       [0.9957154903951778]
# recall_score_micro                                  [0.9820522112001934]
# log_loss                                           [0.06370762127054275]
# norm_macro_recall                                   [0.8714394570923314]
# weighted_accuracy                                   [0.9961606535063761]
# AUC_macro                                           [0.9889786279592153]
# f1_score_macro                                       [0.959519105739625]
# accuracy                                            [0.9820522112001934]
# f1_score_weighted                                   [0.9815356446309877]
# AUC_micro                                           [0.9961879210713402]
# AUC_weighted                                        [0.9889786279592153]
# precision_score_macro                               [0.9875225551747031]
# average_precision_score_weighted                    [0.9940845495969421]
# matthews_correlation                                 [0.921753907906697]
# balanced_accuracy                                   [0.9357197285461657]
# f1_score_micro                                      [0.9820522112001934]
# recall_score_weighted                               [0.9820522112001934]
# precision_score_micro                               [0.9820522112001934]
# recall_score_macro                                  [0.9357197285461657]
# average_precision_score_macro                       [0.9853305271118231]
# precision_score_weighted                            [0.9822927875631937]
#
#                                  19a393c8-0f5a-4a64-b891-a802346138e5_16  \
# average_precision_score_micro                       [0.9978579294549457]
# recall_score_micro                                  [0.9881095458823411]
# log_loss                                           [0.04316025881724485]
# norm_macro_recall                                   [0.9207570148125388]
# weighted_accuracy                                   [0.9965980005501601]
# AUC_macro                                           [0.9939598236383913]
# f1_score_macro                                      [0.9737844069845562]
# accuracy                                            [0.9881095458823411]
# f1_score_weighted                                   [0.9879140650328975]
# AUC_micro                                           [0.9979049247318132]
# AUC_weighted                                        [0.9939598236383915]
# precision_score_macro                               [0.9885344260626473]
# average_precision_score_weighted                    [0.9967762065626162]
# matthews_correlation                                [0.9484443683991994]
# balanced_accuracy                                   [0.9603785074062694]
# f1_score_micro                                      [0.9881095458823411]
# recall_score_weighted                               [0.9881095458823411]
# precision_score_micro                               [0.9881095458823411]
# recall_score_macro                                  [0.9603785074062694]
# average_precision_score_macro                       [0.9913648787088427]
# precision_score_weighted                            [0.9881336781628243]
#
#                                  19a393c8-0f5a-4a64-b891-a802346138e5_12  \
# average_precision_score_micro                         [0.99832608256557]
# recall_score_micro                                  [0.9883337611289779]
# log_loss                                          [0.061801358383168005]
# norm_macro_recall                                   [0.9143593717787265]
# weighted_accuracy                                   [0.9979039283049274]
# AUC_macro                                           [0.9957474332176159]
# f1_score_macro                                      [0.9742129681515609]
# accuracy                                            [0.9883337611289779]
# f1_score_weighted                                   [0.9880945406212478]
# AUC_micro                                           [0.9983833607803323]
# AUC_weighted                                        [0.9957474332176159]
# precision_score_macro                               [0.9933391302153932]
# average_precision_score_weighted                    [0.9977940471784696]
# matthews_correlation                                 [0.949787727851646]
# balanced_accuracy                                   [0.9571796858893633]
# f1_score_micro                                      [0.9883337611289779]
# recall_score_weighted                               [0.9883337611289779]
# precision_score_micro                               [0.9883337611289779]
# recall_score_macro                                  [0.9571796858893633]
# average_precision_score_macro                       [0.9943198937263491]
# precision_score_weighted                            [0.9885041665478248]
#
#                                  19a393c8-0f5a-4a64-b891-a802346138e5_28  \
# average_precision_score_micro                        [0.998308883251297]
# recall_score_micro                                  [0.9883337611289779]
# log_loss                                           [0.05594217259125115]
# norm_macro_recall                                   [0.9143593717787265]
# weighted_accuracy                                   [0.9979039283049274]
# AUC_macro                                           [0.9957601386998673]
# f1_score_macro                                      [0.9742129681515609]
# accuracy                                            [0.9883337611289779]
# f1_score_weighted                                   [0.9880945406212478]
# AUC_micro                                           [0.9983646252500439]
# AUC_weighted                                        [0.9957597319349588]
# precision_score_macro                               [0.9933391302153932]
# average_precision_score_weighted                    [0.9977943867810065]
# matthews_correlation                                 [0.949787727851646]
# balanced_accuracy                                   [0.9571796858893633]
# f1_score_micro                                      [0.9883337611289779]
# recall_score_weighted                               [0.9883337611289779]
# precision_score_micro                               [0.9883337611289779]
# recall_score_macro                                  [0.9571796858893633]
# average_precision_score_macro                       [0.9943095935822626]
# precision_score_weighted                            [0.9885041665478248]
#
#                                  19a393c8-0f5a-4a64-b891-a802346138e5_33  \
# average_precision_score_micro                       [0.9982195217505708]
# recall_score_micro                                  [0.9876608637445707]
# log_loss                                            [0.0439440784479362]
# norm_macro_recall                                   [0.9091387665581214]
# weighted_accuracy                                   [0.9977919809058147]
# AUC_macro                                           [0.9957706566085255]
# f1_score_macro                                       [0.972594184222034]
# accuracy                                            [0.9876608637445707]
# f1_score_weighted                                   [0.9873942195240166]
# AUC_micro                                           [0.9982784619366539]
# AUC_weighted                                        [0.9957706566085255]
# precision_score_macro                               [0.9929627819448668]
# average_precision_score_weighted                    [0.9977891174523241]
# matthews_correlation                                [0.9467102576405774]
# balanced_accuracy                                   [0.9545693832790606]
# f1_score_micro                                      [0.9876608637445707]
# recall_score_weighted                               [0.9876608637445707]
# precision_score_micro                               [0.9876608637445707]
# recall_score_macro                                  [0.9545693832790606]
# average_precision_score_macro                       [0.9942844285662578]
# precision_score_weighted                            [0.9878485454348944]
#
#                                  19a393c8-0f5a-4a64-b891-a802346138e5_37  \
# average_precision_score_micro                        [0.998498486867273]
# recall_score_micro                                  [0.9908018903534599]
# log_loss                                           [0.03502063596909942]
# norm_macro_recall                                   [0.9439682643896206]
# weighted_accuracy                                   [0.9966285172182747]
# AUC_macro                                           [0.9945046076150339]
# f1_score_macro                                      [0.9801723451119544]
# accuracy                                            [0.9908018903534599]
# f1_score_weighted                                   [0.9907049675999502]
# AUC_micro                                            [0.998529713670553]
# AUC_weighted                                        [0.9945046076150339]
# precision_score_macro                               [0.9889636986684615]
# average_precision_score_weighted                    [0.9972148520339623]
# matthews_correlation                                [0.9607380938558017]
# balanced_accuracy                                   [0.9719841321948103]
# f1_score_micro                                      [0.9908018903534599]
# recall_score_weighted                               [0.9908018903534599]
# precision_score_micro                               [0.9908018903534599]
# recall_score_macro                                  [0.9719841321948103]
# average_precision_score_macro                        [0.992812176971993]
# precision_score_weighted                            [0.9907942143506399]
#
#                                  19a393c8-0f5a-4a64-b891-a802346138e5_36
# average_precision_score_micro                       [0.9981524618518488]
# recall_score_micro                                  [0.9890069101578817]
# log_loss                                            [0.0757832799083887]
# norm_macro_recall                                   [0.9202839404007002]
# weighted_accuracy                                   [0.9978213640390378]
# AUC_macro                                           [0.9949470727976845]
# f1_score_macro                                      [0.9757525408309252]
# accuracy                                            [0.9890069101578817]
# f1_score_weighted                                   [0.9888095263472845]
# AUC_micro                                           [0.9982284770941133]
# AUC_weighted                                        [0.9949470727976845]
# precision_score_macro                               [0.9930381393747603]
# average_precision_score_weighted                     [0.997427181762431]
# matthews_correlation                                [0.9525926178860976]
# balanced_accuracy                                   [0.9601419702003501]
# f1_score_micro                                      [0.9890069101578817]
# recall_score_weighted                               [0.9890069101578817]
# precision_score_micro                               [0.9890069101578817]
# recall_score_macro                                  [0.9601419702003501]
# average_precision_score_macro                       [0.9933636361663656]
# precision_score_weighted                            [0.9891241245207001]
#
# [21 rows x 35 columns]

# %% [markdown]
# **Retrieve the Best Model**

# %%
# Retrieve best model from Pipeline Run
best_model = pipeline_run.get_pipeline_output(best_model_output_name)
num_file_downloaded = best_model.download('.', show_progress=True)
# Out:
# Downloading azureml/19a393c8-0f5a-4a64-b891-a802346138e5/emailspam_model_data
# Downloaded azureml/19a393c8-0f5a-4a64-b891-a802346138e5/emailspam_model_data, 1 files out of an estimated total of 1

# %% [markdown]
# **Test the Model**

# %%
train_data, test_data = dataset.random_split(percentage=0.8, seed=1)

# %%
df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#           v1                      v2  \
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30
#
#                                                   Column3  \
# count                                                  50
# unique                                                 43
# top      bt not his girlfrnd... G o o d n i g h t . . .@"
# freq                                                    3
#
#                       Column4  Column5
# count                      12        6
# unique                     10        5
# top      MK17 92H. 450Ppw 16"  GNT:-)"
# freq                        2        2

# %%
df = df.replace('spam', 1)
df = df.replace('ham', 0)
df
# Out:
#       v1                                                 v2 Column3 Column4  \
# 0      0  Go until jurong point, crazy.. Available only ...    None    None
# 1      0                      Ok lar... Joking wif u oni...    None    None
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...    None    None
# 3      0  U dun say so early hor... U c already then say...    None    None
# 4      0  Nah I don't think he goes to usf, he lives aro...    None    None
# ...   ..                                                ...     ...     ...
# 5567   1  This is the 2nd time we have tried 2 contact u...    None    None
# 5568   0              Will Ì_ b going to esplanade fr home?    None    None
# 5569   0  Pity, * was in mood for that. So...any other s...    None    None
# 5570   0  The guy did some bitching but I acted like i'd...    None    None
# 5571   0                         Rofl. Its true to its name    None    None
#
#      Column5
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# ...      ...
# 5567    None
# 5568    None
# 5569    None
# 5570    None
# 5571    None
#
# [5572 rows x 5 columns]

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer()
tokenizer.oov_token = '<oovToken>'
tokenizer.fit_on_texts(df.v2)
vocab = tokenizer.word_index
vocabCount = len(vocab)+1

vocabCount
# Out:
# 8922

# %%
SPLIT = 5000

xTrain = tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences(df.v2.to_numpy()), padding='pre', maxlen=171)
yTrain = df.v1.to_numpy()
dim = xTrain.shape[1]
xTest = xTrain[SPLIT:]
yTest = yTrain[SPLIT:]

xTrain = xTrain[:SPLIT]
yTrain = yTrain[:SPLIT]

xTrain.shape, yTrain.shape, xTest.shape, yTest.shape
# Out:
# ((5000, 171), (5000,), (572, 171), (572,))

# %%
from sklearn.metrics import confusion_matrix
yPred = best_model.predict(xTest)
cm = confusion_matrix(yTest, yPred)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /var/folders/_0/vcv08z6j1yjgvd02l9l1vzy183dlc1/T/ipykernel_17810/1021917731.py in <module>
#       1 from sklearn.metrics import confusion_matrix
# ----> 2 yPred = best_model.predict(xTest)
#       3 cm = confusion_matrix(yTest, yPred)
#
# NameError: name 'best_model' is not defined

# %% [markdown]
# **--------------------------------------------------------------------------------------**
