# %% [markdown]
# # Tune Hyperparameters
#
# There are many machine learning algorithms that require *hyperparameters* (parameter values that influence training, but can't be determined from the training data itself). For example, when training a logistic regression model, you can use a *regularization rate* hyperparameter to counteract bias in the model; or when training a convolutional neural network, you can use hyperparameters like *learning rate* and *batch size* to control how weights are adjusted and how many data items are processed in a mini-batch respectively. The choice of hyperparameter values can significantly affect the performance of a trained model, or the time taken to train it; and often you need to try multiple combinations to find the optimal solution.
#
# In this case, you'll train a classification model with two hyperparameters, but the principles apply to any kind of model you can train with Azure Machine Learning.

# %% [markdown]
# ## Connect to your workspace
#
# To get started, connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

import logging
import os
import csv
from datetime import datetime
import pytz


from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import seaborn as sns
import tensorflow as tf

import matplotlib.pyplot as plt
import re
import pydot
import graphviz

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))

print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')

print("Tensorflow version: ", tf.__version__)
print("Current DateTime: ", datetime.now(pytz.timezone("America/New_York")).strftime("%m/%d/%Y %H:%M:%S"))
# Out:
# Ready to use Azure ML 1.41.0 to work with nahmed30-azureml-workspace
# nahmed30-azureml-workspace
# epe-poc-nazeer
# centralus
# 16bc73b5-82be-47f2-b5ab-f2373344794c
# Tensorflow version:  2.2.0
# Current DateTime:  09/02/2022 16:22:07

# %%
from tensorflow import keras
from tensorflow.keras import layers
from keras_tuner.tuners import RandomSearch

from sklearn.preprocessing import StandardScaler
from tensorflow.keras import models, layers
from keras_tuner import HyperModel, RandomSearch, Hyperband, BayesianOptimization

# %% [markdown]
# ## Prepare data
#
# In this lab, you'll use a dataset containing details of diabetes patients. Run the cell below to create this dataset (if it already exists, the existing version will be used)

# %%
from azureml.core import Dataset

# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "UdacityPrjEmailSpamDataSet"
description_text = "Spam Detection DataSet for Udacity Capstone Proj "

dataset = None
if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#           v1                      v2  \
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30
#
#                                                   Column3 Column4  Column5
# count                                                  50      12        6
# unique                                                 43      10        5
# top      bt not his girlfrnd... G o o d n i g h t . . .@"      GE  GNT:-)"
# freq                                                    3       2        2

# %% [markdown]
# ## Prepare a training script
#
# Now let's create a folder for the training script you'll use to train the model.

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_folder = 'spam_training-hyperdrive'
experiment_name = 'ml-spam-experiment-prjassign1'
project_folder = 'spam_training-hyperdrive'

os.makedirs(project_folder, exist_ok=True)

print('Project Folder is ready.')

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Project Folder is ready.
# Experiment(Name: ml-spam-experiment-prjassign1,
# Workspace: nahmed30-azureml-workspace)

# %% [markdown]
# ## Create compute
#
# Hyperparameter tuning involves running multiple training iterations with different hyperparameter values and comparing the performance metrics of the resulting models. To do this efficiently, we'll take advantage of on-demand cloud compute and create a cluster - this will allow multiple training iterations to be run concurrently.
#
# Use the following code to specify an Azure Machine Learning compute cluster (it will be created if it doesn't already exist).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "cpu-cluster"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded......................................................................................................................
# AmlCompute wait for completion finished
#
# Wait timeout has been reached
# Current provisioning state of AmlCompute is "Succeeded" and current node count is "0"

# %% [markdown]
# > **Note**: Compute instances and clusters are based on standard Azure virtual machine images. For this exercise, the *Standard_DS11_v2* image is recommended to achieve the optimal balance of cost and performance. If your subscription has a quota that does not include this image, choose an alternative image; but bear in mind that a larger image may incur higher cost and a smaller image may not be sufficient to complete the tasks. Alternatively, ask your Azure administrator to extend your quota.
#
# You'll need a Python environment to be hosted on the compute, so let's define that as Conda configuration file.

# %%
# %%writefile $project_folder/azureml_hyperdrive_env.yml
# name: batch_environment
# dependencies:
# - python
# - scikit-learn
# - pandas
# - numpy
# - tensorflow
# - pip
# - pip:
#   - azureml-defaults
# Out:
# Writing spam_training-hyperdrive/azureml_hyperdrive_env.yml

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#      v1                                                 v2 Column3 Column4  \
# 0   ham  Go until jurong point, crazy.. Available only ...    None    None
# 1   ham                      Ok lar... Joking wif u oni...    None    None
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...    None    None
# 3   ham  U dun say so early hor... U c already then say...    None    None
# 4   ham  Nah I don't think he goes to usf, he lives aro...    None    None
#
#   Column5
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None

# %%
df.head()
# Out:
#      v1                                                 v2 Column3 Column4  \
# 0   ham  Go until jurong point, crazy.. Available only ...    None    None
# 1   ham                      Ok lar... Joking wif u oni...    None    None
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...    None    None
# 3   ham  U dun say so early hor... U c already then say...    None    None
# 4   ham  Nah I don't think he goes to usf, he lives aro...    None    None
#
#   Column5
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None

# %%
plt.figure(figsize=(18, 8))
plt.subplot(1, 2, 1)
df.v1.value_counts().plot(kind="pie",
                                           fontsize=16,
                                           labels=["Spam", "Ham"],
                                           ylabel="Spam vs Ham",
                                           autopct='%1.1f%%');

plt.subplot(1, 2, 2)
sns.countplot(x="v1",data=df, palette="pastel")
plt.show()

# %%
plt.figure(figsize=(18, 8))
plt.subplot(1, 2, 1)
ax1 = df.query("v1=='spam'").v2.map(lambda x: len(x.split())).plot(kind="hist",
                                                                    color="cyan",
                                                                    title="Spam",
                                                                    edgecolor='white');
plt.subplot(1, 2, 2)
ax2 = df.query("v1=='ham'").v2.map(lambda x: len(x.split())).plot(kind="hist",
                                                                    color="orange",
                                                                    title="Ham",
                                                                    edgecolor='white');

ax1.grid(visible = True, color ='grey',linestyle ='-.', linewidth = 0.5,alpha = 0.6)
ax2.grid(visible = True, color ='grey',linestyle ='-.', linewidth = 0.5,alpha = 0.6)
plt.suptitle('Word distribution in SMS')
plt.show()

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from wordcloud import WordCloud
stop_words= set(stopwords.words("english"))

stop_words.update(['https', 'http', 'amp', 'CO', 't', 'u', 'new', "I'm", "would"])

wc = WordCloud(width=800,
               height=400,
               max_words=200,
               stopwords=stop_words,
               background_color='white',
               max_font_size=150)
spam = df.query("v1=='spam'").v2.str.cat(sep=" ")

ham = df.query("v1=='ham'").v2.str.cat(sep=" ")

print('\n\nWord Cloud for Spam messages\n\n')
wc.generate(spam)
plt.figure(figsize=(16, 8))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

print('\n\nWord Cloud for Ham messages\n\n')
wc.generate(ham)
plt.figure(figsize=(16, 8))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /home/azureuser/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %%
df = df.replace('spam', 1)
df = df.replace('ham', 0)
df
# Out:
#       v1                                                 v2 Column3 Column4  \
# 0      0  Go until jurong point, crazy.. Available only ...    None    None
# 1      0                      Ok lar... Joking wif u oni...    None    None
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...    None    None
# 3      0  U dun say so early hor... U c already then say...    None    None
# 4      0  Nah I don't think he goes to usf, he lives aro...    None    None
# ...   ..                                                ...     ...     ...
# 5567   1  This is the 2nd time we have tried 2 contact u...    None    None
# 5568   0              Will Ì_ b going to esplanade fr home?    None    None
# 5569   0  Pity, * was in mood for that. So...any other s...    None    None
# 5570   0  The guy did some bitching but I acted like i'd...    None    None
# 5571   0                         Rofl. Its true to its name    None    None
#
#      Column5
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# ...      ...
# 5567    None
# 5568    None
# 5569    None
# 5570    None
# 5571    None
#
# [5572 rows x 5 columns]

# %%
def cleanText(text):
    whitespace = re.compile(r"\s+")
    web_address = re.compile(r"(?i)http(s):\/\/[a-z0-9.~_\-\/]+")
    user = re.compile(r"(?i)@[a-z0-9_]+")
    text = text.replace('.', '')
    text = whitespace.sub(' ', text)
    text = web_address.sub('', text)
    text = user.sub('', text)
    text = re.sub(r"\[[^()]*\]", "", text)
    text = re.sub(r"\d+", "", text)
    text = re.sub(r'[^\w\s]','',text)
    text = re.sub(r"(?:@\S*|#\S*|http(?=.*://)\S*)", "", text)
    return text.lower()

df.v2 = [cleanText(item) for item in df.v2]
df
# Out:
#       v1                                                 v2 Column3 Column4  \
# 0      0  go until jurong point crazy available only in ...    None    None
# 1      0                            ok lar joking wif u oni    None    None
# 2      1  free entry in  a wkly comp to win fa cup final...    None    None
# 3      0        u dun say so early hor u c already then say    None    None
# 4      0  nah i dont think he goes to usf he lives aroun...    None    None
# ...   ..                                                ...     ...     ...
# 5567   1  this is the nd time we have tried  contact u u...    None    None
# 5568   0               will ì_ b going to esplanade fr home    None    None
# 5569   0  pity  was in mood for that soany other suggest...    None    None
# 5570   0  the guy did some bitching but i acted like id ...    None    None
# 5571   0                          rofl its true to its name    None    None
#
#      Column5
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# ...      ...
# 5567    None
# 5568    None
# 5569    None
# 5570    None
# 5571    None
#
# [5572 rows x 5 columns]

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer()
tokenizer.oov_token = '<oovToken>'
tokenizer.fit_on_texts(df.v2)
vocab = tokenizer.word_index
vocabCount = len(vocab)+1

vocabCount
# Out:
# 8606

# %%
SPLIT = 5000

xTrain = tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences(df.v2.to_numpy()), padding='pre', maxlen=171)
yTrain = df.v1.to_numpy()
dim = xTrain.shape[1]
xTest = xTrain[SPLIT:]
yTest = yTrain[SPLIT:]

xTrain = xTrain[:SPLIT]
yTrain = yTrain[:SPLIT]

xTrain.shape, yTrain.shape, xTest.shape, yTest.shape
# Out:
# ((5000, 171), (5000,), (572, 171), (572,))

# %% [markdown]
# **Straight to hyperparameter tuning **

# %%
model = tf.keras.Sequential()
model.add(tf.keras.layers.Embedding(input_dim=vocabCount+1, output_dim=64, input_length=dim))
model.add(tf.keras.layers.GlobalAveragePooling1D())
model.add(tf.keras.layers.Dense(64, activation='relu'))
model.add(tf.keras.layers.Dense(32, activation='relu'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])

model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 171, 64)           550848
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 64)                4160
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2080
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 557,121
# Trainable params: 557,121
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# **Building the Hypermodel**

# %%
def build_myhm(hp):
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Embedding(input_dim=vocabCount+1, output_dim=64, input_length=dim))
    model.add(tf.keras.layers.GlobalAveragePooling1D())
    units_l1=hp.Int('units', min_value=8,max_value=128, step=8)
    model.add(tf.keras.layers.Dense(units=units_l1, activation='relu', input_dim=8))
    model.add(tf.keras.layers.Dense(32, activation='relu'))
    model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

    optim=hp.Choice('optimizer', values = ['adam', 'sgd', 'rmsprop', 'adadelta'])

    model.compile( optim, loss='binary_crossentropy', metrics=['accuracy'])

    model.summary()

    return model

# %%
from keras_tuner import RandomSearch
from keras_tuner import Objective

tuner =  RandomSearch(build_myhm,
                      objective='val_accuracy',
                      max_trials=5,
                      project_name='spam_randomsearch',
                      directory='spam_randomsearch_dir',
                      overwrite=True
                    )
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 171, 64)           550848
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 8)                 520
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                288
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 551,689
# Trainable params: 551,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
# xTrain.shape, yTrain.shape, xTest.shape, yTest.shape
tuner.search(xTrain, yTrain, batch_size=32, epochs=10, validation_data=(xTest, yTest))
# Out:
# Trial 5 Complete [00h 00m 05s]
# val_accuracy: 0.8706293702125549
#
# Best val_accuracy So Far: 0.9895104765892029
# Total elapsed time: 00h 00m 34s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.get_best_hyperparameters()[0].values
# Out:
# {'units': 72, 'optimizer': 'adam'}

# %%
best_model=tuner.get_best_models(num_models=1)[0]
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 171, 64)           550848
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 72)                4680
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2336
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 557,897
# Trainable params: 557,897
# Non-trainable params: 0
# _________________________________________________________________

# %%
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 171, 64)           550848
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 72)                4680
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2336
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 557,897
# Trainable params: 557,897
# Non-trainable params: 0
# _________________________________________________________________

# %%
best_model.fit(xTrain, yTrain, batch_size=32, epochs=100, initial_epoch=6, validation_data=(xTest, yTest))
# Out:
# Epoch 7/100
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0079 - accuracy: 0.9976 - val_loss: 0.0368 - val_accuracy: 0.9878
# Epoch 8/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0081 - accuracy: 0.9982 - val_loss: 0.0364 - val_accuracy: 0.9878
# Epoch 9/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0064 - accuracy: 0.9982 - val_loss: 0.0397 - val_accuracy: 0.9843
# Epoch 10/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0053 - accuracy: 0.9986 - val_loss: 0.0453 - val_accuracy: 0.9878
# Epoch 11/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0050 - accuracy: 0.9986 - val_loss: 0.0468 - val_accuracy: 0.9860
# Epoch 12/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0058 - accuracy: 0.9988 - val_loss: 0.0403 - val_accuracy: 0.9860
# Epoch 13/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0047 - accuracy: 0.9988 - val_loss: 0.0414 - val_accuracy: 0.9878
# Epoch 14/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0058 - accuracy: 0.9984 - val_loss: 0.0478 - val_accuracy: 0.9860
# Epoch 15/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0026 - accuracy: 0.9994 - val_loss: 0.0444 - val_accuracy: 0.9843
# Epoch 16/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.0451 - val_accuracy: 0.9843
# Epoch 17/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0024 - accuracy: 0.9994 - val_loss: 0.0612 - val_accuracy: 0.9878
# Epoch 18/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0035 - accuracy: 0.9992 - val_loss: 0.0850 - val_accuracy: 0.9860
# Epoch 19/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0032 - accuracy: 0.9996 - val_loss: 0.0615 - val_accuracy: 0.9878
# Epoch 20/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0035 - accuracy: 0.9988 - val_loss: 0.0424 - val_accuracy: 0.9843
# Epoch 21/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0032 - accuracy: 0.9990 - val_loss: 0.0515 - val_accuracy: 0.9878
# Epoch 22/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0458 - val_accuracy: 0.9860
# Epoch 23/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.0893 - val_accuracy: 0.9790
# Epoch 24/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0028 - accuracy: 0.9994 - val_loss: 0.0725 - val_accuracy: 0.9878
# Epoch 25/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0023 - accuracy: 0.9996 - val_loss: 0.0619 - val_accuracy: 0.9895
# Epoch 26/100
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0723 - val_accuracy: 0.9843
# Epoch 27/100
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0015 - accuracy: 0.9992 - val_loss: 0.0590 - val_accuracy: 0.9895
# Epoch 28/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0015 - accuracy: 0.9994 - val_loss: 0.0642 - val_accuracy: 0.9878
# Epoch 29/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0017 - accuracy: 0.9992 - val_loss: 0.0690 - val_accuracy: 0.9878
# Epoch 30/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0014 - accuracy: 0.9996 - val_loss: 0.0805 - val_accuracy: 0.9878
# Epoch 31/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0013 - accuracy: 0.9998 - val_loss: 0.0696 - val_accuracy: 0.9895
# Epoch 32/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0024 - accuracy: 0.9990 - val_loss: 0.0729 - val_accuracy: 0.9825
# Epoch 33/100
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0016 - accuracy: 0.9994 - val_loss: 0.0623 - val_accuracy: 0.9825
# Epoch 34/100
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0039 - accuracy: 0.9990 - val_loss: 0.0739 - val_accuracy: 0.9860
# Epoch 35/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0014 - accuracy: 0.9992 - val_loss: 0.0717 - val_accuracy: 0.9860
# Epoch 36/100
# 157/157 [==============================] - 1s 5ms/step - loss: 6.2870e-04 - accuracy: 0.9998 - val_loss: 0.0685 - val_accuracy: 0.9843
# Epoch 37/100
# 157/157 [==============================] - 1s 4ms/step - loss: 5.2392e-04 - accuracy: 0.9998 - val_loss: 0.0708 - val_accuracy: 0.9878
# Epoch 38/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0010 - accuracy: 0.9998 - val_loss: 0.1107 - val_accuracy: 0.9860
# Epoch 39/100
# 157/157 [==============================] - 1s 4ms/step - loss: 9.8697e-04 - accuracy: 0.9998 - val_loss: 0.0674 - val_accuracy: 0.9843
# Epoch 40/100
# 157/157 [==============================] - 1s 4ms/step - loss: 8.0326e-04 - accuracy: 0.9998 - val_loss: 0.1096 - val_accuracy: 0.9860
# Epoch 41/100
# 157/157 [==============================] - 1s 4ms/step - loss: 5.6865e-04 - accuracy: 1.0000 - val_loss: 0.0808 - val_accuracy: 0.9860
# Epoch 42/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0020 - accuracy: 0.9996 - val_loss: 0.
- accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9860

# %%
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding (Embedding)        (None, 171, 64)           550848
# _________________________________________________________________
# global_average_pooling1d (Gl (None, 64)                0
# _________________________________________________________________
# dense (Dense)                (None, 72)                4680
# _________________________________________________________________
# dense_1 (Dense)              (None, 32)                2336
# _________________________________________________________________
# dense_2 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 557,897
# Trainable params: 557,897
# Non-trainable params: 0
# _________________________________________________________________

# %%
best_model.evaluate(xTest, yTest)
# Out:
# 18/18 [==============================] - 0s 963us/step - loss: 0.1182 - accuracy: 0.9860
# [0.11817733198404312, 0.9860140085220337]

# %% [markdown]
# https://benalexkeen.com/deploying-neural-network-models-to-azure-ml-service-with-keras-and-onnx/

# %%
# !pip install onnxmltools
# Out:
# Requirement already satisfied: onnxmltools in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (1.4.1)
# Requirement already satisfied: onnxconverter-common>=1.4.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from onnxmltools) (1.6.0)
# Requirement already satisfied: six in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from onnxmltools) (1.16.0)
# Requirement already satisfied: skl2onnx in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from onnxmltools) (1.4.9)
# Requirement already satisfied: protobuf in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from onnxmltools) (3.20.0)
# Requirement already satisfied: numpy in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from onnxmltools) (1.19.0)
# Requirement already satisfied: keras2onnx in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from onnxmltools) (1.6.0)
# Requirement already satisfied: onnx in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from onnxmltools) (1.7.0)
# Requirement already satisfied: scikit-learn>=0.19 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from skl2onnx->onnxmltools) (1.0.2)
# Requirement already satisfied: requests in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from keras2onnx->onnxmltools) (2.27.1)
# Requirement already satisfied: fire in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from keras2onnx->onnxmltools) (0.4.0)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from onnx->onnxmltools) (4.2.0)
# Requirement already satisfied: scipy>=1.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-learn>=0.19->skl2onnx->onnxmltools) (1.5.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-learn>=0.19->skl2onnx->onnxmltools) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-learn>=0.19->skl2onnx->onnxmltools) (0.14.1)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->keras2onnx->onnxmltools) (3.3)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->keras2onnx->onnxmltools) (2.0.12)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->keras2onnx->onnxmltools) (2021.10.8)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->keras2onnx->onnxmltools) (1.26.7)
# Requirement already satisfied: termcolor in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from fire->keras2onnx->onnxmltools) (1.1.0)

# %%
#install this way
# !pip install tensorflow==2.2
# !pip install keras==2.3.1
# !pip install -U segmentation-models
# Out:
# Requirement already satisfied: tensorflow==2.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (2.2.0)
# Collecting scipy==1.4.1; python_version >= "3"
#   Using cached scipy-1.4.1-cp38-cp38-manylinux1_x86_64.whl (26.0 MB)
# Requirement already satisfied: h5py<2.11.0,>=2.10.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorflow==2.2) (2.10.0)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorflow==2.2) (1.19.0)
# Requirement already satisfied: astunparse==1.6.3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorflow==2.2) (1.6.3)
# Requirement already satisfied: grpcio>=1.8.6 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorflow==2.2) (1.44.0)
# Requirement already satisfied: wrapt>=1.11.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorflow==2.2) (1.12.1)
# Requirement already satisfied: six>=1.12.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorflow==2.2) (1.16.0)
# Requirement already satisfied: wheel>=0.26; python_version >= "3" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorflow==2.2) (0.35.1)
# Requirement already satisfied: absl-py>=0.7.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorflow==2.2) (0.15.0)
# Requirement already satisfied: tensorflow-estimator<2.3.0,>=2.2.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorflow==2.2) (2.2.0)
# Requirement already satisfied: termcolor>=1.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorflow==2.2) (1.1.0)
# Requirement already satisfied: tensorboard<2.3.0,>=2.2.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorflow==2.2) (2.2.2)
# Requirement already satisfied: protobuf>=3.8.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorflow==2.2) (3.20.0)
# Requirement already satisfied: keras-preprocessing>=1.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorflow==2.2) (1.1.2)
# Requirement already satisfied: google-pasta>=0.1.8 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorflow==2.2) (0.2.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorflow==2.2) (3.3.0)
# Requirement already satisfied: gast==0.3.3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorflow==2.2) (0.3.3)
# Requirement already satisfied: tensorboard-plugin-wit>=1.6.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2) (1.8.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2) (2.27.1)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2) (1.35.0)
# Requirement already satisfied: markdown>=2.6.8 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2) (3.3.7)
# Requirement already satisfied: werkzeug>=0.11.15 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2) (1.0.1)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2) (0.4.6)
# Requirement already satisfied: setuptools>=41.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from tensorboard<2.3.0,>=2.2.0->tensorflow==2.2) (61.2.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2) (3.3)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests<3,>=2.21.0->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2) (2.0.12)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2) (0.2.8)
# Requirement already satisfied: cachetools<5.0,>=2.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2) (4.2.4)
# Requirement already satisfied: rsa<5,>=3.1.4; python_version >= "3.6" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2) (4.8)
# Requirement already satisfied: importlib-metadata>=4.4; python_version < "3.10" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2) (4.11.3)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2) (1.3.1)
# Requirement already satisfied: pyasn1<0.5.0,>=0.4.6 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from pyasn1-modules>=0.2.1->google-auth<2,>=1.6.3->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2) (0.4.8)
# Requirement already satisfied: zipp>=0.5 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from importlib-metadata>=4.4; python_version < "3.10"->markdown>=2.6.8->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2) (3.8.0)
# Requirement already satisfied: oauthlib>=3.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.3.0,>=2.2.0->tensorflow==2.2) (3.2.0)
# ERROR: pyldavis 3.3.1 requires sklearn, which is not installed.
# ERROR: responsibleai 0.17.0 has requirement ipykernel<6.0, but you'll have ipykernel 6.6.0 which is incompatible.
# ERROR: raiwidgets 0.17.0 has requirement ipykernel<6.0, but you'll have ipykernel 6.6.0 which is incompatible.
# ERROR: raiwidgets 0.17.0 has requirement jinja2==2.11.3, but you'll have jinja2 2.11.2 which is incompatible.
# ERROR: pyldavis 3.3.1 has requirement numpy>=1.20.0, but you'll have numpy 1.19.0 which is incompatible.
# ERROR: pyldavis 3.3.1 has requirement pandas>=1.2.0, but you'll have pandas 1.1.5 which is incompatible.
# ERROR: pycaret 2.3.10 has requirement pyyaml<6.0.0, but you'll have pyyaml 6.0 which is incompatible.
# ERROR: pycaret 2.3.10 has requirement scikit-learn==0.23.2, but you'll have scikit-learn 1.0.2 which is incompatible.
# ERROR: pmdarima 1.7.1 has requirement Cython<0.29.18,>=0.29, but you'll have cython 0.29.28 which is incompatible.
# ERROR: pmdarima 1.7.1 has requirement setuptools<50.0.0, but you'll have setuptools 61.2.0 which is incompatible.
# ERROR: phik 0.12.2 has requirement scipy>=1.5.2, but you'll have scipy 1.4.1 which is incompatible.
# ERROR: pandas-profiling 3.2.0 has requirement joblib~=1.1.0, but you'll have joblib 0.14.1 which is incompatible.
# ERROR: pandas-profiling 3.2.0 has requirement markupsafe~=2.1.1, but you'll have markupsafe 2.0.1 which is incompatible.
# ERROR: azureml-training-tabular 1.41.0 has requirement scikit-learn<0.23.0,>=0.19.0, but you'll have scikit-learn 1.0.2 which is incompatible.
# ERROR: azureml-train-automl-runtime 1.41.0 has requirement scikit-learn<0.23.0,>=0.19.0, but you'll have scikit-learn 1.0.2 which is incompatible.
# ERROR: azureml-datadrift 1.41.0 has requirement matplotlib<=3.2.1,>=3.0.2, but you'll have matplotlib 3.3.4 which is incompatible.
# ERROR: azureml-automl-runtime 1.41.0 has requirement scikit-learn<0.23.0,>=0.19.0, but you'll have scikit-learn 1.0.2 which is incompatible.
# ERROR: autokeras 1.0.16 has requirement tensorflow<=2.5.0,>=2.3.0, but you'll have tensorflow 2.2.0 which is incompatible.
# ERROR: arviz 0.11.2 has requirement typing-extensions<4,>=3.7.4.3, but you'll have typing-extensions 4.2.0 which is incompatible.
# Installing collected packages: scipy
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.5.2
#     Uninstalling scipy-1.5.2:
#       Successfully uninstalled scipy-1.5.2
# Successfully installed scipy-1.4.1
# Requirement already satisfied: keras==2.3.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (2.3.1)
# Requirement already satisfied: numpy>=1.9.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from keras==2.3.1) (1.19.0)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from keras==2.3.1) (1.1.2)
# Requirement already satisfied: six>=1.9.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from keras==2.3.1) (1.16.0)
# Requirement already satisfied: pyyaml in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from keras==2.3.1) (6.0)
# Requirement already satisfied: keras-applications>=1.0.6 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from keras==2.3.1) (1.0.8)
# Requirement already satisfied: h5py in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from keras==2.3.1) (2.10.0)
# Requirement already satisfied: scipy>=0.14 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from keras==2.3.1) (1.4.1)
# Requirement already up-to-date: segmentation-models in /home/azureuser/.local/lib/python3.8/site-packages (1.0.1)
# Requirement already satisfied, skipping upgrade: efficientnet==1.0.0 in /home/azureuser/.local/lib/python3.8/site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied, skipping upgrade: image-classifiers==1.0.0 in /home/azureuser/.local/lib/python3.8/site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied, skipping upgrade: keras-applications<=1.0.8,>=1.0.7 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from segmentation-models) (1.0.8)
# Requirement already satisfied, skipping upgrade: scikit-image in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from efficientnet==1.0.0->segmentation-models) (0.19.2)
# Requirement already satisfied, skipping upgrade: h5py in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (2.10.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.19.0)
# Requirement already satisfied, skipping upgrade: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (6.2.1)
# Requirement already satisfied, skipping upgrade: scipy>=1.4.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.4.1)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (21.3)
# Requirement already satisfied, skipping upgrade: PyWavelets>=1.1.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.3.0)
# Requirement already satisfied, skipping upgrade: imageio>=2.4.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.19.1)
# Requirement already satisfied, skipping upgrade: networkx>=2.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.5)
# Requirement already satisfied, skipping upgrade: tifffile>=2019.7.26 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2022.5.4)
# Requirement already satisfied, skipping upgrade: six in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.16.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=3.0.5,>=2.0.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from packaging>=20.0->scikit-image->efficientnet==1.0.0->segmentation-models) (3.0.8)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from networkx>=2.2->scikit-image->efficientnet==1.0.0->segmentation-models) (5.1.1)

# %%
# !pip install -U segmentation-models
# Out:
# Requirement already up-to-date: segmentation-models in /home/azureuser/.local/lib/python3.8/site-packages (1.0.1)
# Requirement already satisfied, skipping upgrade: keras-applications<=1.0.8,>=1.0.7 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from segmentation-models) (1.0.8)
# Requirement already satisfied, skipping upgrade: efficientnet==1.0.0 in /home/azureuser/.local/lib/python3.8/site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied, skipping upgrade: image-classifiers==1.0.0 in /home/azureuser/.local/lib/python3.8/site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied, skipping upgrade: numpy>=1.9.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.19.0)
# Requirement already satisfied, skipping upgrade: h5py in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (2.10.0)
# Requirement already satisfied, skipping upgrade: scikit-image in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from efficientnet==1.0.0->segmentation-models) (0.19.2)
# Requirement already satisfied, skipping upgrade: six in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.16.0)
# Requirement already satisfied, skipping upgrade: scipy>=1.4.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.4.1)
# Requirement already satisfied, skipping upgrade: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (6.2.1)
# Requirement already satisfied, skipping upgrade: tifffile>=2019.7.26 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2022.5.4)
# Requirement already satisfied, skipping upgrade: packaging>=20.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (21.3)
# Requirement already satisfied, skipping upgrade: imageio>=2.4.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.19.1)
# Requirement already satisfied, skipping upgrade: networkx>=2.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.5)
# Requirement already satisfied, skipping upgrade: PyWavelets>=1.1.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.3.0)
# Requirement already satisfied, skipping upgrade: pyparsing!=3.0.5,>=2.0.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from packaging>=20.0->scikit-image->efficientnet==1.0.0->segmentation-models) (3.0.8)
# Requirement already satisfied, skipping upgrade: decorator>=4.3.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from networkx>=2.2->scikit-image->efficientnet==1.0.0->segmentation-models) (5.1.1)

# %%
import os 
# !pip install -U -q segmentation-models --user
os.environ["SM_FRAMEWORK"] = "tf.keras"
import segmentation_models as sm

# %%
# !pip install segmentation-models
# Out:
# Requirement already satisfied: segmentation-models in /home/azureuser/.local/lib/python3.8/site-packages (1.0.1)
# Requirement already satisfied: image-classifiers==1.0.0 in /home/azureuser/.local/lib/python3.8/site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: keras-applications<=1.0.8,>=1.0.7 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from segmentation-models) (1.0.8)
# Requirement already satisfied: efficientnet==1.0.0 in /home/azureuser/.local/lib/python3.8/site-packages (from segmentation-models) (1.0.0)
# Requirement already satisfied: numpy>=1.9.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.19.0)
# Requirement already satisfied: h5py in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from keras-applications<=1.0.8,>=1.0.7->segmentation-models) (2.10.0)
# Requirement already satisfied: scikit-image in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from efficientnet==1.0.0->segmentation-models) (0.19.2)
# Requirement already satisfied: six in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from h5py->keras-applications<=1.0.8,>=1.0.7->segmentation-models) (1.16.0)
# Requirement already satisfied: pillow!=7.1.0,!=7.1.1,!=8.3.0,>=6.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (6.2.1)
# Requirement already satisfied: PyWavelets>=1.1.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.3.0)
# Requirement already satisfied: packaging>=20.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (21.3)
# Requirement already satisfied: tifffile>=2019.7.26 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2022.5.4)
# Requirement already satisfied: scipy>=1.4.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (1.4.1)
# Requirement already satisfied: imageio>=2.4.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.19.1)
# Requirement already satisfied: networkx>=2.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-image->efficientnet==1.0.0->segmentation-models) (2.5)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from packaging>=20.0->scikit-image->efficientnet==1.0.0->segmentation-models) (3.0.8)
# Requirement already satisfied: decorator>=4.3.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from networkx>=2.2->scikit-image->efficientnet==1.0.0->segmentation-models) (5.1.1)

# %%
import tensorflow as tf
import tensorflow.keras as keras
#import segmentation_models as sm

# %%
# !pip install onnxmltools
# Out:
# Requirement already satisfied: onnxmltools in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (1.4.1)
# Requirement already satisfied: protobuf in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from onnxmltools) (3.20.0)
# Requirement already satisfied: six in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from onnxmltools) (1.16.0)
# Requirement already satisfied: onnx in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from onnxmltools) (1.7.0)
# Requirement already satisfied: numpy in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from onnxmltools) (1.19.0)
# Requirement already satisfied: keras2onnx in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from onnxmltools) (1.6.0)
# Requirement already satisfied: onnxconverter-common>=1.4.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from onnxmltools) (1.6.0)
# Requirement already satisfied: skl2onnx in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from onnxmltools) (1.4.9)
# Requirement already satisfied: typing-extensions>=3.6.2.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from onnx->onnxmltools) (4.2.0)
# Requirement already satisfied: fire in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from keras2onnx->onnxmltools) (0.4.0)
# Requirement already satisfied: requests in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from keras2onnx->onnxmltools) (2.27.1)
# Requirement already satisfied: scikit-learn>=0.19 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from skl2onnx->onnxmltools) (1.0.2)
# Requirement already satisfied: termcolor in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from fire->keras2onnx->onnxmltools) (1.1.0)
# Requirement already satisfied: certifi>=2017.4.17 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->keras2onnx->onnxmltools) (2021.10.8)
# Requirement already satisfied: charset-normalizer~=2.0.0; python_version >= "3" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->keras2onnx->onnxmltools) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->keras2onnx->onnxmltools) (1.26.7)
# Requirement already satisfied: idna<4,>=2.5; python_version >= "3" in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from requests->keras2onnx->onnxmltools) (3.3)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-learn>=0.19->skl2onnx->onnxmltools) (2.2.0)
# Requirement already satisfied: joblib>=0.11 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-learn>=0.19->skl2onnx->onnxmltools) (0.14.1)
# Requirement already satisfied: scipy>=1.1.0 in /anaconda/envs/azureml_py38/lib/python3.8/site-packages (from scikit-learn>=0.19->skl2onnx->onnxmltools) (1.4.1)

# %%
import onnxmltools


onnx_model = onnxmltools.convert_keras(best_model) 

onnxmltools.utils.save_model(onnx_model, 'keras_emailspam_model.onnx')

# %%
text = "Congratulations, you have won a 10000 dollars lottery. Please give your bank details to claim the money"
processedText = cleanText(text)
#print(processedText)
finalText = tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([processedText]), padding='pre', maxlen=171)
prediction = best_model.predict(finalText)
print("prediction shape", prediction.shape)
print(prediction)

print(np.int(np.rint(prediction[0,0])))
# Out:
# prediction shape (1, 1)
# [[0.9999988]]
# 1

# %%
text = "I'll meet you at nariman point tomorrow"
processedText = cleanText(text)
#print(processedText)
finalText = tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([processedText]), padding='pre', maxlen=171)
prediction = best_model.predict(finalText)
print("prediction shape", prediction.shape)
print(prediction)
print(np.int(np.rint(prediction[0,0])))
# Out:
# prediction shape (1, 1)
# [[1.7309684e-08]]
# 0

# %%
text = "You won $100 click link below to collect"
processedText = cleanText(text)
#print(processedText)
finalText = tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([processedText]), padding='pre', maxlen=171)
prediction = best_model.predict(finalText)
print("prediction shape", prediction.shape)
print(prediction)
print(np.int(np.rint(prediction[0,0])))
# Out:
# prediction shape (1, 1)
# [[0.9999962]]
# 1

# %% [markdown]
# ## Run a hyperparameter tuning experiment
#
# Azure Machine Learning includes a hyperparameter tuning capability through *hyperdrive* experiments. These experiments launch multiple child runs, each with a different hyperparameter combination. The run producing the best model (as determined by the logged target performance metric for which you want to optimize) can be identified, and its trained model selected for registration and deployment.
#
# > **Note**: In this example, we aren't specifying an early stopping policy. Such a policy is only relevant if the training script performs multiple training iterations, logging the primary metric for each iteration. This approach is typically employed when training deep neural network models over multiple *epochs*.

# %% [markdown]
# https://www.tensorflow.org/tutorials/keras/keras_tuner

# %%
import keras_tuner as kt

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(xTrain, yTrain, epochs=50, validation_split=0.2, callbacks=[stop_early])

# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]
# Out:
# INFO:tensorflow:Oracle triggered exit

# %%
print("The hyperparameter search is complete. The optimal number of units in the first densely-connected layer is  and the optimal learning rate for the optimizer is.")
# Out:
# The hyperparameter search is complete. The optimal number of units in the first densely-connected layer is  and the optimal learning rate for the optimizer is.

# %%
best_hps.get('units')
#best_hps.get('learning_rate')
# Out:
# 72

# %%
# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
modelhp = tuner.hypermodel.build(best_hps)
history = modelhp.fit(xTrain, yTrain, epochs=50, validation_split=0.2)

val_acc_per_epoch = history.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# embedding_1 (Embedding)      (None, 171, 64)           550848
# _________________________________________________________________
# global_average_pooling1d_1 ( (None, 64)                0
# _________________________________________________________________
# dense_3 (Dense)              (None, 72)                4680
# _________________________________________________________________
# dense_4 (Dense)              (None, 32)                2336
# _________________________________________________________________
# dense_5 (Dense)              (None, 1)                 33
# =================================================================
# Total params: 557,897
# Trainable params: 557,897
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 125/125 [==============================] - 1s 5ms/step - loss: 0.4608 - accuracy: 0.8543 - val_loss: 0.3827 - val_accuracy: 0.8620
# Epoch 2/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.3529 - accuracy: 0.8662 - val_loss: 0.3246 - val_accuracy: 0.8620
# Epoch 3/50
# 125/125 [==============================] - 1s 4ms/step - loss: 0.1861 - accuracy: 0.9225 - val_loss: 0.0900 - val_accuracy: 0.9780
# Epoch 4/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0583 - accuracy: 0.9825 - val_loss: 0.0620 - val_accuracy: 0.9860
# Epoch 5/50
# 125/125 [==============================] - 1s 4ms/step - loss: 0.0377 - accuracy: 0.9895 - val_loss: 0.0595 - val_accuracy: 0.9820
# Epoch 6/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0322 - accuracy: 0.9912 - val_loss: 0.0531 - val_accuracy: 0.9840
# Epoch 7/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0223 - accuracy: 0.9927 - val_loss: 0.0673 - val_accuracy: 0.9830
# Epoch 8/50
# 125/125 [==============================] - 1s 4ms/step - loss: 0.0193 - accuracy: 0.9925 - val_loss: 0.0610 - val_accuracy: 0.9830
# Epoch 9/50
# 125/125 [==============================] - 1s 4ms/step - loss: 0.0145 - accuracy: 0.9952 - val_loss: 0.0551 - val_accuracy: 0.9860
# Epoch 10/50
# 125/125 [==============================] - 1s 4ms/step - loss: 0.0142 - accuracy: 0.9955 - val_loss: 0.0570 - val_accuracy: 0.9860
# Epoch 11/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0112 - accuracy: 0.9967 - val_loss: 0.0561 - val_accuracy: 0.9860
# Epoch 12/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0095 - accuracy: 0.9975 - val_loss: 0.0576 - val_accuracy: 0.9860
# Epoch 13/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0074 - accuracy: 0.9975 - val_loss: 0.0708 - val_accuracy: 0.9840
# Epoch 14/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0077 - accuracy: 0.9980 - val_loss: 0.0672 - val_accuracy: 0.9780
# Epoch 15/50
# 125/125 [==============================] - 1s 4ms/step - loss: 0.0061 - accuracy: 0.9985 - val_loss: 0.0800 - val_accuracy: 0.9830
# Epoch 16/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0066 - accuracy: 0.9973 - val_loss: 0.0753 - val_accuracy: 0.9840
# Epoch 17/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0061 - accuracy: 0.9985 - val_loss: 0.0650 - val_accuracy: 0.9820
# Epoch 18/50
# 125/125 [==============================] - 1s 4ms/step - loss: 0.0073 - accuracy: 0.9985 - val_loss: 0.0671 - val_accuracy: 0.9810
# Epoch 19/50
# 125/125 [==============================] - 1s 4ms/step - loss: 0.0052 - accuracy: 0.9992 - val_loss: 0.0674 - val_accuracy: 0.9860
# Epoch 20/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 0.9995 - val_loss: 0.0728 - val_accuracy: 0.9840
# Epoch 21/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0058 - accuracy: 0.9985 - val_loss: 0.1076 - val_accuracy: 0.9800
# Epoch 22/50
# 125/125 [==============================] - 1s 4ms/step - loss: 0.0036 - accuracy: 0.9995 - val_loss: 0.0708 - val_accuracy: 0.9820
# Epoch 23/50
# 125/125 [==============================] - 1s 4ms/step - loss: 0.0033 - accuracy: 0.9990 - val_loss: 0.1130 - val_accuracy: 0.9800
# Epoch 24/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0059 - accuracy: 0.9977 - val_loss: 0.0973 - val_accuracy: 0.9830
# Epoch 25/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0041 - accuracy: 0.9987 - val_loss: 0.0869 - val_accuracy: 0.9840
# Epoch 26/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0025 - accuracy: 0.9992 - val_loss: 0.0783 - val_accuracy: 0.9840
# Epoch 27/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0030 - accuracy: 0.9992 - val_loss: 0.0779 - val_accuracy: 0.9850
# Epoch 28/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0019 - accuracy: 0.9995 - val_loss: 0.0858 - val_accuracy: 0.9850
# Epoch 29/50
# 125/125 [==============================] - 1s 4ms/step - loss: 0.0034 - accuracy: 0.9992 - val_loss: 0.1182 - val_accuracy: 0.9810
# Epoch 30/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.1032 - val_accuracy: 0.9830
# Epoch 31/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 0.9995 - val_loss: 0.1187 - val_accuracy: 0.9820
# Epoch 32/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0038 - accuracy: 0.9987 - val_loss: 0.0917 - val_accuracy: 0.9850
# Epoch 33/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0029 - accuracy: 0.9990 - val_loss: 0.1195 - val_accuracy: 0.9640
# Epoch 34/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0033 - accuracy: 0.9992 - val_loss: 0.0926 - val_accuracy: 0.9850
# Epoch 35/50
# 125/125 [==============================] - 1s 4ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.1036 - val_accuracy: 0.9830
# Epoch 36/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0017 - accuracy: 0.9995 - val_loss: 0.0945 - val_accuracy: 0.9840
# Epoch 37/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0015 - accuracy: 0.9995 - val_loss: 0.1038 - val_accuracy: 0.9840
# Epoch 38/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0018 - accuracy: 0.9995 - val_loss: 0.1072 - val_accuracy: 0.9840
# Epoch 39/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0022 - accuracy: 0.9990 - val_loss: 0.0972 - val_accuracy: 0.9840
# Epoch 40/50
# 125/125 [==============================] - 0s 4ms/step - loss: 9.6455e-04 - accuracy: 0.9995 - val_loss: 0.1367 - val_accuracy: 0.9610
# Epoch 41/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0020 - accuracy: 0.9992 - val_loss: 0.1254 - val_accuracy: 0.9700
# Epoch 42/50
# 125/125 [==============================] - 1s 4ms/step - loss: 6.6918e-04 - accuracy: 0.9998 - val_loss: 0.1095 - val_accuracy: 0.9840
# Epoch 43/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0039 - accuracy: 0.9990 - val_loss: 0.1030 - val_accuracy: 0.9850
# Epoch 44/50
# 125/125 [==============================] - 0s 4ms/step - loss: 6.2893e-04 - accuracy: 0.9998 - val_loss: 0.1055 - val_accuracy: 0.9850
# Epoch 45/50
# 125/125 [==============================] - 0s 4ms/step - loss: 2.5439e-04 - accuracy: 1.0000 - val_loss: 0.1115 - val_accuracy: 0.9820
# Epoch 46/50
# 125/125 [==============================] - 0s 4ms/step - loss: 3.6648e-04 - accuracy: 1.0000 - val_loss: 0.1257 - val_accuracy: 0.9830
# Epoch 47/50
# 125/125 [==============================] - 0s 4ms/step - loss: 2.9226e-04 - accuracy: 1.0000 - val_loss: 0.1182 - val_accuracy: 0.9820
# Epoch 48/50
# 125/125 [==============================] - 1s 4ms/step - loss: 0.0018 - accuracy: 0.9992 - val_loss: 0.2631 - val_accuracy: 0.9710
# Epoch 49/50
# 125/125 [==============================] - 1s 4ms/step - loss: 0.0024 - accuracy: 0.9992 - val_loss: 0.1208 - val_accuracy: 0.9820
# Epoch 50/50
# 125/125 [==============================] - 0s 4ms/step - loss: 8.4994e-04 - accuracy: 1.0000 - val_loss: 0.1127 - val_accuracy: 0.9840
# Best epoch: 4

# %%
eval_result = modelhp.evaluate(xTest, yTest)
print("[test loss, test accuracy]:", eval_result)
# Out:
# 18/18 [==============================] - 0s 1ms/step - loss: 0.0905 - accuracy: 0.9860
# [test loss, test accuracy]: [0.09045233577489853, 0.9860140085220337]

# %% [markdown]
# **Register Model**

# %%
import os

os.makedirs('./outputs',exist_ok=True)

# %%
modelhp.name
# Out:
# 'sequential_1'

# %%
model_name = best_run.properties['model_name']
script_file = "./outputs/score.py"
description = "aml email spam project sdk"

# %%
text = "You won $100 click link below to collect"
processedText = cleanText(text)
#print(processedText)
finalText = tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([processedText]), padding='pre', maxlen=171)
prediction = modelhp.predict(finalText)
print("prediction shape", prediction.shape)
print(prediction)
print(prediction[0,0])
print(np.int(np.rint(prediction[0,0])))
# Out:
# prediction shape (1, 1)
# [[0.9977703]]
# 0.9977703
# 1

# %%
text = "I'll meet you at nariman point tomorrow"
processedText = cleanText(text)
#print(processedText)
finalText = tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([processedText]), padding='pre', maxlen=171)
prediction = modelhp.predict(finalText)
print("prediction shape", prediction.shape)
print(prediction)
print(np.int(np.rint(prediction[0,0])))
# Out:
# prediction shape (1, 1)
# [[1.2275301e-05]]
# 0

# %% [markdown]
# Now that you've found the best run, you can register the model it trained.

# %% [markdown]
# > **More Information**: For more information about Hyperdrive, see the [Azure ML documentation](https://docs.microsoft.com/azure/machine-learning/how-to-tune-hyperparameters).
