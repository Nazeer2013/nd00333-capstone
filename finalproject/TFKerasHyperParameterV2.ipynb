# %% [markdown]
# # Tune Hyperparameters
#
# There are many machine learning algorithms that require *hyperparameters* (parameter values that influence training, but can't be determined from the training data itself). For example, when training a logistic regression model, you can use a *regularization rate* hyperparameter to counteract bias in the model; or when training a convolutional neural network, you can use hyperparameters like *learning rate* and *batch size* to control how weights are adjusted and how many data items are processed in a mini-batch respectively. The choice of hyperparameter values can significantly affect the performance of a trained model, or the time taken to train it; and often you need to try multiple combinations to find the optimal solution.
#
# In this case, you'll train a classification model with two hyperparameters, but the principles apply to any kind of model you can train with Azure Machine Learning.

# %% [markdown]
# ## Connect to your workspace
#
# To get started, connect to your workspace.
#
# > **Note**: If you haven't already established an authenticated session with your Azure subscription, you'll be prompted to authenticate by clicking a link, entering an authentication code, and signing into Azure.

# %%
import azureml.core
from azureml.core import Workspace

import logging
import os
import csv
from datetime import datetime
import pytz


from matplotlib import pyplot as plt
import numpy as np
import pandas as pd
from sklearn import datasets
import pkg_resources

import seaborn as sns
import tensorflow as tf

import matplotlib.pyplot as plt
import re
import pydot
import graphviz

import azureml.core
from azureml.core.experiment import Experiment
from azureml.core.workspace import Workspace
from azureml.train.automl import AutoMLConfig
from azureml.core.dataset import Dataset

from azureml.pipeline.steps import AutoMLStep


# Check core SDK version number
# print("SDK version:", azureml.core.VERSION)

# Load the workspace from the saved config file
ws = Workspace.from_config()
print('Ready to use Azure ML {} to work with {}'.format(azureml.core.VERSION, ws.name))

print(ws.name, ws.resource_group, ws.location, ws.subscription_id, sep = '\n')

print("Tensorflow version: ", tf.__version__)
print("Current DateTime: ", datetime.now(pytz.timezone("America/New_York")).strftime("%m/%d/%Y %H:%M:%S"))
# Out:
# Ready to use Azure ML 1.44.0 to work with nahmed30-azureml-workspace
# nahmed30-azureml-workspace
# epe-poc-nazeer
# centralus
# 16bc73b5-82be-47f2-b5ab-f2373344794c
# Tensorflow version:  2.7.0
# Current DateTime:  09/15/2022 14:04:55

# %%
from tensorflow import keras
from tensorflow.keras import layers
from keras_tuner.tuners import RandomSearch

from sklearn.preprocessing import StandardScaler
from tensorflow.keras import models, layers
from keras_tuner import HyperModel, RandomSearch, Hyperband, BayesianOptimization

# %% [markdown]
# ## Prepare data
#
# In this lab, you'll use a dataset containing details of diabetes patients. Run the cell below to create this dataset (if it already exists, the existing version will be used)

# %%
from azureml.core import Dataset

# Try to load the dataset from the Workspace. Otherwise, create it from the file
# NOTE: update the key to match the dataset name
found = False
key = "UdacityPrjEmailSpamDataSet"
description_text = "Spam Detection DataSet for Udacity Capstone Proj "

dataset = None
if key in ws.datasets.keys(): 
        found = True
        dataset = ws.datasets[key] 

df = dataset.to_pandas_dataframe()
df.describe()
# Out:
#           v1                      v2  \
# count   5572                    5572
# unique     2                    5169
# top      ham  Sorry, I'll call later
# freq    4825                      30
#
#                                                   Column3 Column4  Column5
# count                                                  50      12        6
# unique                                                 43      10        5
# top      bt not his girlfrnd... G o o d n i g h t . . .@"      GE  GNT:-)"
# freq                                                    3       2        2

# %%
df
# Out:
#         v1                                                 v2 Column3 Column4  \
# 0      ham  Go until jurong point, crazy.. Available only ...    None    None
# 1      ham                      Ok lar... Joking wif u oni...    None    None
# 2     spam  Free entry in 2 a wkly comp to win FA Cup fina...    None    None
# 3      ham  U dun say so early hor... U c already then say...    None    None
# 4      ham  Nah I don't think he goes to usf, he lives aro...    None    None
# ...    ...                                                ...     ...     ...
# 5567  spam  This is the 2nd time we have tried 2 contact u...    None    None
# 5568   ham              Will Ì_ b going to esplanade fr home?    None    None
# 5569   ham  Pity, * was in mood for that. So...any other s...    None    None
# 5570   ham  The guy did some bitching but I acted like i'd...    None    None
# 5571   ham                         Rofl. Its true to its name    None    None
#
#      Column5
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# ...      ...
# 5567    None
# 5568    None
# 5569    None
# 5570    None
# 5571    None
#
# [5572 rows x 5 columns]

# %% [markdown]
# ## Prepare a training script
#
# Now let's create a folder for the training script you'll use to train the model.

# %%
# Choose a name for the run history container in the workspace.
# NOTE: update these to match your existing experiment name
experiment_folder = 'sms_spam_keras_hyperdrive_0915_v2'
experiment_name = 'sms-spam-exp-0915-v2'
project_folder = 'sms_spam_keras_hyperdrive_0915_v2'

os.makedirs(project_folder, exist_ok=True)

print('Project Folder is ready.')

experiment = Experiment(ws, experiment_name)
experiment
# Out:
# Project Folder is ready.
# Experiment(Name: sms-spam-exp-0915-v2,
# Workspace: nahmed30-azureml-workspace)

# %% [markdown]
# ## Create compute
#
# Hyperparameter tuning involves running multiple training iterations with different hyperparameter values and comparing the performance metrics of the resulting models. To do this efficiently, we'll take advantage of on-demand cloud compute and create a cluster - this will allow multiple training iterations to be run concurrently.
#
# Use the following code to specify an Azure Machine Learning compute cluster (it will be created if it doesn't already exist).
#
# > **Important**: Change *your-compute-cluster* to the name of your compute cluster in the code below before running it! Cluster names must be globally unique names between 2 to 16 characters in length. Valid characters are letters, digits, and the - character.

# %%
from azureml.core.compute import AmlCompute
from azureml.core.compute import ComputeTarget
from azureml.core.compute_target import ComputeTargetException

# NOTE: update the cluster name to match the existing cluster
# Choose a name for your CPU cluster
amlcompute_cluster_name = "cpu-cluster"

# Verify that cluster does not exist already
try:
    compute_target = ComputeTarget(workspace=ws, name=amlcompute_cluster_name)
    print('Found existing cluster, use it.')
except ComputeTargetException:
    compute_config = AmlCompute.provisioning_configuration(vm_size='STANDARD_D2_V2',# for GPU, use "STANDARD_NC6"
                                                           #vm_priority = 'lowpriority', # optional
                                                           max_nodes=4)
    compute_target = ComputeTarget.create(ws, amlcompute_cluster_name, compute_config)

compute_target.wait_for_completion(show_output=True, min_node_count = 1, timeout_in_minutes = 10)
# For a more detailed view of current AmlCompute status, use get_status().
# Out:
# Found existing cluster, use it.
# Succeeded......................................................................................................
# AmlCompute wait for completion finished
#
# Wait timeout has been reached
# Current provisioning state of AmlCompute is "Succeeded" and current node count is "0"

# %% [markdown]
# > **Note**: Compute instances and clusters are based on standard Azure virtual machine images. For this exercise, the *Standard_DS11_v2* image is recommended to achieve the optimal balance of cost and performance. If your subscription has a quota that does not include this image, choose an alternative image; but bear in mind that a larger image may incur higher cost and a smaller image may not be sufficient to complete the tasks. Alternatively, ask your Azure administrator to extend your quota.
#
# You'll need a Python environment to be hosted on the compute, so let's define that as Conda configuration file.

# %%
# %%writefile $project_folder/hyperdrive_env.yml
# name: batch_environment
# dependencies:
# - python
# - scikit-learn
# - pandas
# - numpy
# - pip
# - pip:
#   - azureml-defaults

# %%
dataset.take(5).to_pandas_dataframe()
# Out:
#      v1                                                 v2 Column3 Column4  \
# 0   ham  Go until jurong point, crazy.. Available only ...    None    None
# 1   ham                      Ok lar... Joking wif u oni...    None    None
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...    None    None
# 3   ham  U dun say so early hor... U c already then say...    None    None
# 4   ham  Nah I don't think he goes to usf, he lives aro...    None    None
#
#   Column5
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None

# %%
df.head()
# Out:
#      v1                                                 v2 Column3 Column4  \
# 0   ham  Go until jurong point, crazy.. Available only ...    None    None
# 1   ham                      Ok lar... Joking wif u oni...    None    None
# 2  spam  Free entry in 2 a wkly comp to win FA Cup fina...    None    None
# 3   ham  U dun say so early hor... U c already then say...    None    None
# 4   ham  Nah I don't think he goes to usf, he lives aro...    None    None
#
#   Column5
# 0    None
# 1    None
# 2    None
# 3    None
# 4    None

# %%
plt.figure(figsize=(18, 8))
plt.subplot(1, 2, 1)
df.v1.value_counts().plot(kind="pie",
                                           fontsize=16,
                                           labels=["Spam", "Ham"],
                                           ylabel="Spam vs Ham",
                                           autopct='%1.1f%%');

plt.subplot(1, 2, 2)
sns.countplot(x="v1",data=df, palette="pastel")
plt.show()

# %%
plt.figure(figsize=(18, 8))
plt.subplot(1, 2, 1)
ax1 = df.query("v1=='spam'").v2.map(lambda x: len(x.split())).plot(kind="hist",
                                                                    color="cyan",
                                                                    title="Spam",
                                                                    edgecolor='white');
plt.subplot(1, 2, 2)
ax2 = df.query("v1=='ham'").v2.map(lambda x: len(x.split())).plot(kind="hist",
                                                                    color="orange",
                                                                    title="Ham",
                                                                    edgecolor='white');

ax1.grid(visible = True, color ='grey',linestyle ='-.', linewidth = 0.5,alpha = 0.6)
ax2.grid(visible = True, color ='grey',linestyle ='-.', linewidth = 0.5,alpha = 0.6)
plt.suptitle('Word distribution in SMS')
plt.show()

# %%
import nltk
nltk.download('stopwords')
from nltk.corpus import stopwords
from wordcloud import WordCloud
stop_words= set(stopwords.words("english"))

stop_words.update(['https', 'http', 'amp', 'CO', 't', 'u', 'new', "I'm", "would"])

wc = WordCloud(width=800,
               height=400,
               max_words=200,
               stopwords=stop_words,
               background_color='white',
               max_font_size=150)
spam = df.query("v1=='spam'").v2.str.cat(sep=" ")

ham = df.query("v1=='ham'").v2.str.cat(sep=" ")

print('\n\nWord Cloud for Spam messages\n\n')
wc.generate(spam)
plt.figure(figsize=(16, 8))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()

print('\n\nWord Cloud for Ham messages\n\n')
wc.generate(ham)
plt.figure(figsize=(16, 8))
plt.imshow(wc, interpolation='bilinear')
plt.axis('off')
plt.show()
# Out:
# [nltk_data] Downloading package stopwords to
# [nltk_data]     /Users/nahmed4/nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!
# Word Cloud for Spam messages
# Word Cloud for Ham messages

# %%
df = df.replace('spam', 1)
df = df.replace('ham', 0)
df
# Out:
#       v1                                                 v2 Column3 Column4  \
# 0      0  Go until jurong point, crazy.. Available only ...    None    None
# 1      0                      Ok lar... Joking wif u oni...    None    None
# 2      1  Free entry in 2 a wkly comp to win FA Cup fina...    None    None
# 3      0  U dun say so early hor... U c already then say...    None    None
# 4      0  Nah I don't think he goes to usf, he lives aro...    None    None
# ...   ..                                                ...     ...     ...
# 5567   1  This is the 2nd time we have tried 2 contact u...    None    None
# 5568   0              Will Ì_ b going to esplanade fr home?    None    None
# 5569   0  Pity, * was in mood for that. So...any other s...    None    None
# 5570   0  The guy did some bitching but I acted like i'd...    None    None
# 5571   0                         Rofl. Its true to its name    None    None
#
#      Column5
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# ...      ...
# 5567    None
# 5568    None
# 5569    None
# 5570    None
# 5571    None
#
# [5572 rows x 5 columns]

# %%
def clean_text(text):
    whitespace = re.compile(r"\s+")
    web_address = re.compile(r"(?i)http(s):\/\/[a-z0-9.~_\-\/]+")
    user = re.compile(r"(?i)@[a-z0-9_]+")
    text = text.replace('.', '')
    text = whitespace.sub(' ', text)
    text = web_address.sub('', text)
    text = user.sub('', text)
    text = re.sub(r"\[[^()]*\]", "", text)
    text = re.sub(r"\d+", "", text)
    text = re.sub(r'[^\w\s]','',text)
    text = re.sub(r"(?:@\S*|#\S*|http(?=.*://)\S*)", "", text)
    return text.lower()

df.v2 = [clean_text(item) for item in df.v2]
df
# Out:
#       v1                                                 v2 Column3 Column4  \
# 0      0  go until jurong point crazy available only in ...    None    None
# 1      0                            ok lar joking wif u oni    None    None
# 2      1  free entry in  a wkly comp to win fa cup final...    None    None
# 3      0        u dun say so early hor u c already then say    None    None
# 4      0  nah i dont think he goes to usf he lives aroun...    None    None
# ...   ..                                                ...     ...     ...
# 5567   1  this is the nd time we have tried  contact u u...    None    None
# 5568   0               will ì_ b going to esplanade fr home    None    None
# 5569   0  pity  was in mood for that soany other suggest...    None    None
# 5570   0  the guy did some bitching but i acted like id ...    None    None
# 5571   0                          rofl its true to its name    None    None
#
#      Column5
# 0       None
# 1       None
# 2       None
# 3       None
# 4       None
# ...      ...
# 5567    None
# 5568    None
# 5569    None
# 5570    None
# 5571    None
#
# [5572 rows x 5 columns]

# %%
tokenizer = tf.keras.preprocessing.text.Tokenizer()
tokenizer.oov_token = '<oovToken>'
tokenizer.fit_on_texts(df.v2)
vocab = tokenizer.word_index
vocabCount = len(vocab)+1

vocabCount
# Out:
# 8606

# %%
SPLIT = 5000

xTrain = tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences(df.v2.to_numpy()), padding='pre', maxlen=171)
yTrain = df.v1.to_numpy()
dim = xTrain.shape[1]
xTest = xTrain[SPLIT:]
yTest = yTrain[SPLIT:]

xTrain = xTrain[:SPLIT]
yTrain = yTrain[:SPLIT]

xTrain.shape, yTrain.shape, xTest.shape, yTest.shape
# Out:
# ((5000, 171), (5000,), (572, 171), (572,))

# %% [markdown]
# **Straight to hyperparameter tuning **

# %% [markdown]
# **Building the Hypermodel**

# %%
def build_myhm(hp):
    model = tf.keras.Sequential()
    model.add(tf.keras.layers.Embedding(input_dim=vocabCount+1, output_dim=64, input_length=dim))
    model.add(tf.keras.layers.GlobalAveragePooling1D())
    units_l1=hp.Int('units', min_value=8,max_value=128, step=8)
    model.add(tf.keras.layers.Dense(units=units_l1, activation='relu', input_dim=8))
    model.add(tf.keras.layers.Dense(32, activation='relu'))
    model.add(tf.keras.layers.Dense(1, activation='sigmoid'))

    optim=hp.Choice('optimizer', values = ['adam', 'sgd', 'rmsprop', 'adadelta'])

    model.compile( optim, loss='binary_crossentropy', metrics=['accuracy'])

    model.summary()

    return model

# %%
from keras_tuner import RandomSearch
from keras_tuner import Objective

tuner =  RandomSearch(build_myhm,
                      objective='val_accuracy',
                      max_trials=5,
                      project_name='spam_randomsearch',
                      directory='spam_randomsearch_dir',
                      overwrite=True
                    )
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 171, 64)           550848
#
#  global_average_pooling1d (G  (None, 64)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 32)                288
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 551,689
# Trainable params: 551,689
# Non-trainable params: 0
# _________________________________________________________________
# 2022-09-15 14:30:07.811473: I tensorflow/core/platform/cpu_feature_guard.cc:151] This TensorFlow binary is optimized with oneAPI Deep Neural Network Library (oneDNN) to use the following CPU instructions in performance-critical operations:  AVX2 FMA
# To enable them in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
# xTrain.shape, yTrain.shape, xTest.shape, yTest.shape
tuner.search(xTrain, yTrain, batch_size=32, epochs=10, validation_data=(xTest, yTest))
# Out:
# Trial 5 Complete [00h 00m 05s]
# val_accuracy: 0.8706293702125549
#
# Best val_accuracy So Far: 0.9877622127532959
# Total elapsed time: 00h 00m 27s
# INFO:tensorflow:Oracle triggered exit

# %%
tuner.get_best_hyperparameters()[0].values
# Out:
# {'units': 8, 'optimizer': 'rmsprop'}

# %%
best_model=tuner.get_best_models(num_models=1)[0]
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 171, 64)           550848
#
#  global_average_pooling1d (G  (None, 64)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 32)                288
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 551,689
# Trainable params: 551,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 171, 64)           550848
#
#  global_average_pooling1d (G  (None, 64)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 32)                288
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 551,689
# Trainable params: 551,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
best_model.fit(xTrain, yTrain, batch_size=32, epochs=100, initial_epoch=6, validation_data=(xTest, yTest))
# Out:
# Epoch 7/100
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0520 - accuracy: 0.9868 - val_loss: 0.0467 - val_accuracy: 0.9843
# Epoch 8/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0498 - accuracy: 0.9868 - val_loss: 0.0447 - val_accuracy: 0.9895
# Epoch 9/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0479 - accuracy: 0.9872 - val_loss: 0.0534 - val_accuracy: 0.9808
# Epoch 10/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0457 - accuracy: 0.9884 - val_loss: 0.0472 - val_accuracy: 0.9825
# Epoch 11/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0445 - accuracy: 0.9878 - val_loss: 0.0493 - val_accuracy: 0.9825
# Epoch 12/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0424 - accuracy: 0.9886 - val_loss: 0.0427 - val_accuracy: 0.9895
# Epoch 13/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0403 - accuracy: 0.9890 - val_loss: 0.0441 - val_accuracy: 0.9843
# Epoch 14/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0392 - accuracy: 0.9900 - val_loss: 0.0432 - val_accuracy: 0.9895
# Epoch 15/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0370 - accuracy: 0.9914 - val_loss: 0.0448 - val_accuracy: 0.9860
# Epoch 16/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0361 - accuracy: 0.9902 - val_loss: 0.0548 - val_accuracy: 0.9860
# Epoch 17/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0363 - accuracy: 0.9906 - val_loss: 0.0525 - val_accuracy: 0.9843
# Epoch 18/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0346 - accuracy: 0.9906 - val_loss: 0.0476 - val_accuracy: 0.9878
# Epoch 19/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0329 - accuracy: 0.9910 - val_loss: 0.0432 - val_accuracy: 0.9860
# Epoch 20/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0326 - accuracy: 0.9912 - val_loss: 0.0434 - val_accuracy: 0.9860
# Epoch 21/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0315 - accuracy: 0.9910 - val_loss: 0.0466 - val_accuracy: 0.9878
# Epoch 22/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0295 - accuracy: 0.9914 - val_loss: 0.0445 - val_accuracy: 0.9843
# Epoch 23/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0308 - accuracy: 0.9910 - val_loss: 0.0588 - val_accuracy: 0.9843
# Epoch 24/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0292 - accuracy: 0.9924 - val_loss: 0.0511 - val_accuracy: 0.9878
# Epoch 25/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0292 - accuracy: 0.9922 - val_loss: 0.0451 - val_accuracy: 0.9860
# Epoch 26/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0276 - accuracy: 0.9914 - val_loss: 0.0497 - val_accuracy: 0.9843
# Epoch 27/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0276 - accuracy: 0.9932 - val_loss: 0.0464 - val_accuracy: 0.9860
# Epoch 28/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0260 - accuracy: 0.9920 - val_loss: 0.0555 - val_accuracy: 0.9808
# Epoch 29/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0252 - accuracy: 0.9918 - val_loss: 0.0666 - val_accuracy: 0.9860
# Epoch 30/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0256 - accuracy: 0.9924 - val_loss: 0.0478 - val_accuracy: 0.9878
# Epoch 31/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0250 - accuracy: 0.9924 - val_loss: 0.0501 - val_accuracy: 0.9878
# Epoch 32/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0246 - accuracy: 0.9926 - val_loss: 0.0505 - val_accuracy: 0.9878
# Epoch 33/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0225 - accuracy: 0.9934 - val_loss: 0.0555 - val_accuracy: 0.9878
# Epoch 34/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 0.9946 - val_loss: 0.0839 - val_accuracy: 0.9843
# Epoch 35/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 0.9944 - val_loss: 0.0536 - val_accuracy: 0.9860
# Epoch 36/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0220 - accuracy: 0.9938 - val_loss: 0.0529 - val_accuracy: 0.9860
# Epoch 37/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0213 - accuracy: 0.9938 - val_loss: 0.0551 - val_accuracy: 0.9860
# Epoch 38/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0204 - accuracy: 0.9932 - val_loss: 0.0539 - val_accuracy: 0.9878
# Epoch 39/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0209 - accuracy: 0.9944 - val_loss: 0.0548 - val_accuracy: 0.9878
# Epoch 40/100
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0193 - accuracy: 0.9944 - val_loss: 0.0648 - val_accuracy: 0.9808
# Epoch 41/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0193 - accuracy: 0.9944 - val_loss: 0.0570 - val_accuracy: 0.9878
# Epoch 42/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 0.9950 - val_loss: 0.0588 - val_accuracy: 0.9878
# Epoch 43/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0185 - accuracy: 0.9938 - val_loss: 0.0585 - val_accuracy: 0.9895
# Epoch 44/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0187 - accuracy: 0.9942 - val_loss: 0.0804 - val_accuracy: 0.9808
# Epoch 45/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0172 - accuracy: 0.9948 - val_loss: 0.0616 - val_accuracy: 0.9878
# Epoch 46/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0172 - accuracy: 0.9948 - val_loss: 0.0621 - val_accuracy: 0.9878
# Epoch 47/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0177 - accuracy: 0.9956 - val_loss: 0.0623 - val_accuracy: 0.9895
# Epoch 48/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0171 - accuracy: 0.9948 - val_loss: 0.0632 - val_accuracy: 0.9860
# Epoch 49/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0163 - accuracy: 0.9948 - val_loss: 0.0652 - val_accuracy: 0.9843
# Epoch 50/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0155 - accuracy: 0.9958 - val_loss: 0.0822 - val_accuracy: 0.9895
# Epoch 51/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 0.9958 - val_loss: 0.0719 - val_accuracy: 0.9790
# Epoch 52/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0149 - accuracy: 0.9956 - val_loss: 0.0757 - val_accuracy: 0.9773
# Epoch 53/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0152 - accuracy: 0.9958 - val_loss: 0.0695 - val_accuracy: 0.9895
# Epoch 54/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0142 - accuracy: 0.9954 - val_loss: 0.0750 - val_accuracy: 0.9878
# Epoch 55/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0138 - accuracy: 0.9958 - val_loss: 0.0717 - val_accuracy: 0.9895
# Epoch 56/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0146 - accuracy: 0.9954 - val_loss: 0.0754 - val_accuracy: 0.9878
# Epoch 57/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0137 - accuracy: 0.9956 - val_loss: 0.0709 - val_accuracy: 0.9878
# Epoch 58/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0139 - accuracy: 0.9958 - val_loss: 0.0711 - val_accuracy: 0.9878
# Epoch 59/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0131 - accuracy: 0.9962 - val_loss: 0.0854 - val_accuracy: 0.9878
# Epoch 60/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0136 - accuracy: 0.9958 - val_loss: 0.0742 - val_accuracy: 0.9843
# Epoch 61/100
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0124 - accuracy: 0.9960 - val_loss: 0.0805 - val_accuracy: 0.9878
# Epoch 62/100
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0125 - accuracy: 0.9960 - val_loss: 0.0766 - val_accuracy: 0.9860
# Epoch 63/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0126 - accuracy: 0.9958 - val_loss: 0.0772 - val_accuracy: 0.9895
# Epoch 64/100
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0108 - accuracy: 0.9970 - val_loss: 0.0838 - val_accuracy: 0.9808
# Epoch 65/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0126 - accuracy: 0.9962 - val_loss: 0.0795 - val_accuracy: 0.9895
# Epoch 66/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0116 - accuracy: 0.9962 - val_loss: 0.0878 - val_accuracy: 0.9878
# Epoch 67/100
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0117 - accuracy: 0.9960 - val_loss: 0.0863 - val_accuracy: 0.9808
# Epoch 68/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 0.9968 - val_loss: 0.0821 - val_accuracy: 0.9860
# Epoch 69/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0105 - accuracy: 0.9968 - val_loss: 0.1290 - val_accuracy: 0.9650
# Epoch 70/100
# 157/157 [==============================] - 1s 5ms/step - loss: 0.0108 - accuracy: 0.9960 - val_loss: 0.0870 - val_accuracy: 0.9808
# Epoch 71/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0103 - accuracy: 0.9970 - val_loss: 0.0867 - val_accuracy: 0.9895
# Epoch 72/100
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0096 - accuracy: 0.9972 - val_loss: 0.1206 - val_accuracy: 0.9685
# Epoch 73/100
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0107 - accuracy: 0.9964 - val_loss: 0.0994 - val_accuracy: 0.9808
# Epoch 74/100
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0096 - accuracy: 0.9968 - val_loss: 0.0876 - val_accuracy: 0.9895
# Epoch 75/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0087 - accuracy: 0.9968 - val_loss: 0.0940 - val_accuracy: 0.9808
# Epoch 76/100
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0092 - accuracy: 0.9974 - val_loss: 0.0981 - val_accuracy: 0.9878
# Epoch 77/100
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0093 - accuracy: 0.9970 - val_loss: 0.0998 - val_accuracy: 0.9878
# Epoch 78/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0088 - accuracy: 0.9968 - val_loss: 0.0929 - val_accuracy: 0.9878
# Epoch 79/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0097 - accuracy: 0.9966 - val_loss: 0.0916 - val_accuracy: 0.9843
# Epoch 80/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0079 - accuracy: 0.9976 - val_loss: 0.1050 - val_accuracy: 0.9878
# Epoch 81/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 0.9970 - val_loss: 0.0932 - val_accuracy: 0.9860
# Epoch 82/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0084 - accuracy: 0.9974 - val_loss: 0.0978 - val_accuracy: 0.9895
# Epoch 83/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0078 - accuracy: 0.9978 - val_loss: 0.0952 - val_accuracy: 0.9895
# Epoch 84/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0076 - accuracy: 0.9976 - val_loss: 0.1074 - val_accuracy: 0.9878
# Epoch 85/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0085 - accuracy: 0.9974 - val_loss: 0.0971 - val_accuracy: 0.9843
# Epoch 86/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0079 - accuracy: 0.9974 - val_loss: 0.0969 - val_accuracy: 0.9895
# Epoch 87/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0074 - accuracy: 0.9976 - val_loss: 0.0984 - val_accuracy: 0.9843
# Epoch 88/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0072 - accuracy: 0.9974 - val_loss: 0.1027 - val_accuracy: 0.9843
# Epoch 89/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0070 - accuracy: 0.9970 - val_loss: 0.0970 - val_accuracy: 0.9860
# Epoch 90/100
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0062 - accuracy: 0.9980 - val_loss: 0.1049 - val_accuracy: 0.9843
# Epoch 91/100
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0058 - accuracy: 0.9980 - val_loss: 0.1110 - val_accuracy: 0.9895
# Epoch 92/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0068 - accuracy: 0.9978 - val_loss: 0.1091 - val_accuracy: 0.9878
# Epoch 93/100
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0063 - accuracy: 0.9980 - val_loss: 0.1155 - val_accuracy: 0.9808
# Epoch 94/100
# 157/157 [==============================] - 0s 2ms/step - loss: 0.0060 - accuracy: 0.9976 - val_loss: 0.1118 - val_accuracy: 0.9878
# Epoch 95/100
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0062 - accuracy: 0.9982 - val_loss: 0.1083 - val_accuracy: 0.9860
# Epoch 96/100
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0069 - accuracy: 0.9976 - val_loss: 0.1088 - val_accuracy: 0.9878
# Epoch 97/100
# 157/157 [==============================] - 1s 4ms/step - loss: 0.0054 - accuracy: 0.9978 - val_loss: 0.1088 - val_accuracy: 0.9895
# Epoch 98/100
# 157/157 [==============================] - 1s 3ms/step - loss: 0.0061 - accuracy: 0.9982 - val_loss: 0.1138 - val_accuracy: 0.9895
# Epoch 99/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0052 - accuracy: 0.9984 - val_loss: 0.1197 - val_accuracy: 0.9808
# Epoch 100/100
# 157/157 [==============================] - 0s 3ms/step - loss: 0.0056 - accuracy: 0.9982 - val_loss: 0.1137 - val_accuracy: 0.9895

# %%
best_model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding (Embedding)       (None, 171, 64)           550848
#
#  global_average_pooling1d (G  (None, 64)               0
#  lobalAveragePooling1D)
#
#  dense (Dense)               (None, 8)                 520
#
#  dense_1 (Dense)             (None, 32)                288
#
#  dense_2 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 551,689
# Trainable params: 551,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
best_model.evaluate(xTest, yTest)
# Out:
# 18/18 [==============================] - 0s 1ms/step - loss: 0.1137 - accuracy: 0.9895
# [0.11371497809886932, 0.9895104765892029]

# %%
text = "Congratulations, you have won a 10000 dollars lottery. Please give your bank details to claim the money"
processedText = clean_text(text)
#print(processedText)
finalText = tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([processedText]), padding='pre', maxlen=171)
prediction = best_model.predict(finalText)
print("prediction shape", prediction.shape)
print(prediction)

print(np.int(np.rint(prediction[0,0])))
# Out:
# prediction shape (1, 1)
# [[0.99995446]]
# 1

# %%
text = "I'll meet you at nariman point tomorrow"
processedText = clean_text(text)
#print(processedText)
finalText = tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([processedText]), padding='pre', maxlen=171)
prediction = best_model.predict(finalText)
print("prediction shape", prediction.shape)
print(prediction)
print(np.int(np.rint(prediction[0,0])))
# Out:
# prediction shape (1, 1)
# [[1.803578e-07]]
# 0

# %%
text = "You won $100 click link below to collect"
processedText = clean_text(text)
#print(processedText)
finalText = tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([processedText]), padding='pre', maxlen=171)
prediction = best_model.predict(finalText)
print("prediction shape", prediction.shape)
print(prediction)
print(np.int(np.rint(prediction[0,0])))
# Out:
# prediction shape (1, 1)
# [[0.99988866]]
# 1

# %% [markdown]
# ## Run a hyperparameter tuning experiment
#
# Azure Machine Learning includes a hyperparameter tuning capability through *hyperdrive* experiments. These experiments launch multiple child runs, each with a different hyperparameter combination. The run producing the best model (as determined by the logged target performance metric for which you want to optimize) can be identified, and its trained model selected for registration and deployment.
#
# > **Note**: In this example, we aren't specifying an early stopping policy. Such a policy is only relevant if the training script performs multiple training iterations, logging the primary metric for each iteration. This approach is typically employed when training deep neural network models over multiple *epochs*.

# %% [markdown]
# https://www.tensorflow.org/tutorials/keras/keras_tuner

# %%
import keras_tuner as kt

# %% [markdown]
# # Early Termination

# %%
stop_early = tf.keras.callbacks.EarlyStopping(monitor='val_loss', patience=5)

# %%
tuner.search(xTrain, yTrain, epochs=50, validation_split=0.2, callbacks=[stop_early])
# Out:
# INFO:tensorflow:Oracle triggered exit

# %%
# Get the optimal hyperparameters
best_hps=tuner.get_best_hyperparameters(num_trials=1)[0]

# %%
best_hps.values
# Out:
# {'units': 8, 'optimizer': 'rmsprop'}

# %%
# Build the model with the optimal hyperparameters and train it on the data for 50 epochs
modelhp = tuner.hypermodel.build(best_hps)
history = modelhp.fit(xTrain, yTrain, epochs=50, validation_split=0.2)

val_acc_per_epoch = history.history['val_accuracy']
best_epoch = val_acc_per_epoch.index(max(val_acc_per_epoch)) + 1
print('Best epoch: %d' % (best_epoch,))
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  embedding_1 (Embedding)     (None, 171, 64)           550848
#
#  global_average_pooling1d_1   (None, 64)               0
#  (GlobalAveragePooling1D)
#
#  dense_3 (Dense)             (None, 8)                 520
#
#  dense_4 (Dense)             (None, 32)                288
#
#  dense_5 (Dense)             (None, 1)                 33
#
# =================================================================
# Total params: 551,689
# Trainable params: 551,689
# Non-trainable params: 0
# _________________________________________________________________
# Epoch 1/50
# 125/125 [==============================] - 1s 4ms/step - loss: 0.4476 - accuracy: 0.8662 - val_loss: 0.3835 - val_accuracy: 0.8620
# Epoch 2/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.3682 - accuracy: 0.8662 - val_loss: 0.3662 - val_accuracy: 0.8620
# Epoch 3/50
# 125/125 [==============================] - 1s 4ms/step - loss: 0.3421 - accuracy: 0.8662 - val_loss: 0.3290 - val_accuracy: 0.8620
# Epoch 4/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.2757 - accuracy: 0.8708 - val_loss: 0.2312 - val_accuracy: 0.8870
# Epoch 5/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1776 - accuracy: 0.9337 - val_loss: 0.1537 - val_accuracy: 0.9490
# Epoch 6/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.1183 - accuracy: 0.9712 - val_loss: 0.1032 - val_accuracy: 0.9710
# Epoch 7/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0802 - accuracy: 0.9800 - val_loss: 0.0793 - val_accuracy: 0.9800
# Epoch 8/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0630 - accuracy: 0.9835 - val_loss: 0.0855 - val_accuracy: 0.9750
# Epoch 9/50
# 125/125 [==============================] - 0s 4ms/step - loss: 0.0566 - accuracy: 0.9850 - val_loss: 0.0721 - val_accuracy: 0.9810
# Epoch 10/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0512 - accuracy: 0.9868 - val_loss: 0.0680 - val_accuracy: 0.9830
# Epoch 11/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0475 - accuracy: 0.9893 - val_loss: 0.0679 - val_accuracy: 0.9810
# Epoch 12/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0447 - accuracy: 0.9883 - val_loss: 0.0687 - val_accuracy: 0.9830
# Epoch 13/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0421 - accuracy: 0.9885 - val_loss: 0.0680 - val_accuracy: 0.9810
# Epoch 14/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0411 - accuracy: 0.9885 - val_loss: 0.0695 - val_accuracy: 0.9820
# Epoch 15/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0377 - accuracy: 0.9895 - val_loss: 0.0689 - val_accuracy: 0.9810
# Epoch 16/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0366 - accuracy: 0.9902 - val_loss: 0.0722 - val_accuracy: 0.9840
# Epoch 17/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0336 - accuracy: 0.9912 - val_loss: 0.0711 - val_accuracy: 0.9830
# Epoch 18/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0325 - accuracy: 0.9912 - val_loss: 0.0724 - val_accuracy: 0.9830
# Epoch 19/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0315 - accuracy: 0.9912 - val_loss: 0.0722 - val_accuracy: 0.9840
# Epoch 20/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0318 - accuracy: 0.9915 - val_loss: 0.0772 - val_accuracy: 0.9860
# Epoch 21/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0302 - accuracy: 0.9915 - val_loss: 0.0733 - val_accuracy: 0.9830
# Epoch 22/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0281 - accuracy: 0.9918 - val_loss: 0.1087 - val_accuracy: 0.9650
# Epoch 23/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0271 - accuracy: 0.9918 - val_loss: 0.0810 - val_accuracy: 0.9850
# Epoch 24/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0268 - accuracy: 0.9923 - val_loss: 0.0776 - val_accuracy: 0.9850
# Epoch 25/50
# 125/125 [==============================] - 1s 5ms/step - loss: 0.0254 - accuracy: 0.9923 - val_loss: 0.0902 - val_accuracy: 0.9770
# Epoch 26/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0236 - accuracy: 0.9927 - val_loss: 0.0817 - val_accuracy: 0.9850
# Epoch 27/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0241 - accuracy: 0.9933 - val_loss: 0.0811 - val_accuracy: 0.9840
# Epoch 28/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0212 - accuracy: 0.9927 - val_loss: 0.0936 - val_accuracy: 0.9830
# Epoch 29/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0214 - accuracy: 0.9942 - val_loss: 0.0832 - val_accuracy: 0.9840
# Epoch 30/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0195 - accuracy: 0.9945 - val_loss: 0.1275 - val_accuracy: 0.9610
# Epoch 31/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0196 - accuracy: 0.9942 - val_loss: 0.0875 - val_accuracy: 0.9840
# Epoch 32/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0182 - accuracy: 0.9942 - val_loss: 0.0965 - val_accuracy: 0.9820
# Epoch 33/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0163 - accuracy: 0.9945 - val_loss: 0.0913 - val_accuracy: 0.9840
# Epoch 34/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0181 - accuracy: 0.9942 - val_loss: 0.0931 - val_accuracy: 0.9830
# Epoch 35/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0160 - accuracy: 0.9950 - val_loss: 0.1013 - val_accuracy: 0.9820
# Epoch 36/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0156 - accuracy: 0.9950 - val_loss: 0.1025 - val_accuracy: 0.9820
# Epoch 37/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0155 - accuracy: 0.9955 - val_loss: 0.1257 - val_accuracy: 0.9800
# Epoch 38/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0154 - accuracy: 0.9948 - val_loss: 0.0967 - val_accuracy: 0.9830
# Epoch 39/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0135 - accuracy: 0.9965 - val_loss: 0.0991 - val_accuracy: 0.9830
# Epoch 40/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0147 - accuracy: 0.9958 - val_loss: 0.1019 - val_accuracy: 0.9830
# Epoch 41/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0136 - accuracy: 0.9952 - val_loss: 0.1028 - val_accuracy: 0.9830
# Epoch 42/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0124 - accuracy: 0.9958 - val_loss: 0.1045 - val_accuracy: 0.9830
# Epoch 43/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0133 - accuracy: 0.9965 - val_loss: 0.1066 - val_accuracy: 0.9820
# Epoch 44/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0099 - accuracy: 0.9970 - val_loss: 0.1312 - val_accuracy: 0.9820
# Epoch 45/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 0.9962 - val_loss: 0.1130 - val_accuracy: 0.9790
# Epoch 46/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0109 - accuracy: 0.9967 - val_loss: 0.1138 - val_accuracy: 0.9820
# Epoch 47/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0101 - accuracy: 0.9973 - val_loss: 0.1188 - val_accuracy: 0.9820
# Epoch 48/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0095 - accuracy: 0.9967 - val_loss: 0.1196 - val_accuracy: 0.9780
# Epoch 49/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0097 - accuracy: 0.9958 - val_loss: 0.1406 - val_accuracy: 0.9820
# Epoch 50/50
# 125/125 [==============================] - 0s 3ms/step - loss: 0.0092 - accuracy: 0.9970 - val_loss: 0.1341 - val_accuracy: 0.9730
# Best epoch: 20

# %%
eval_result = modelhp.evaluate(xTest, yTest)
print("[test loss, test accuracy]:", eval_result)
# Out:
# 18/18 [==============================] - 0s 1ms/step - loss: 0.0908 - accuracy: 0.9808
# [test loss, test accuracy]: [0.09080743044614792, 0.9807692170143127]

# %%
text = "You won $100 click link below to collect"
processedText = clean_text(text)

finalText = tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([processedText]), padding='pre', maxlen=171)

prediction = modelhp.predict(finalText)

print(np.int(np.rint(prediction[0,0])))
if 0 == (np.int32(np.rint(prediction[0,0]))):
    str_result = "Ham"
else:
    str_result = "Spam"  

print("Its: ",str_result)
# Out:
# 1
# Its:  Spam

# %%
text = "I'll meet you at nariman point tomorrow"
processedText = clean_text(text)
#print(processedText)
finalText = tf.keras.preprocessing.sequence.pad_sequences(tokenizer.texts_to_sequences([processedText]), padding='pre', maxlen=171)
prediction = modelhp.predict(finalText)
#print("prediction shape", prediction.shape)
#print(prediction)
#print(np.int(np.rint(prediction[0,0])))
if 0 == (np.int32(np.rint(prediction[0,0]))):
    str_result = "Ham"
else:
    str_result = "Spam"  

print("Its: ",str_result)
# Out:
# Its:  Ham

# %% [markdown]
# Now that you've found the best run, you can register the model it trained.

# %% [markdown]
# > **More Information**: For more information about Hyperdrive, see the [Azure ML documentation](https://docs.microsoft.com/azure/machine-learning/how-to-tune-hyperparameters).
